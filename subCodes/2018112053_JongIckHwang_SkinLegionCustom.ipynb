# %%
# %tensorflow_version 1.x
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
np.random.seed(101)
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('/content/drive/My Drive/input/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

# for i in range(len(filelist_trainx)):
# X_train = np.array([np.array(Image.open(fname)) for fname])


filelist_trainy = sorted(glob.glob('/content/drive/My Drive/input/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

print(len(filelist_trainx))
print(len(filelist_trainy))
# Out:
# 200
# 200

# %%
def resize(filename, size = (224,224)):
    im = Image.open(filename)
    im_resized = im.resize(size, Image.ANTIALIAS)
    return (im_resized)
#   im_resized.save('/resized_ph2/X_train/X_img_'+str(i)+'.bmp', dpi = (192,256))

# %%
X_train_ph2_resized = []
Y_train_ph2_resized = []

for i in range(len(filelist_trainx)):
    X_train_ph2_resized.append(resize(filelist_trainx[i]))
    Y_train_ph2_resized.append(resize(filelist_trainy[i]))

# %%
X_train = np.array([np.array(img) for img in X_train_ph2_resized])
Y_train = np.array([np.array(img) for img in Y_train_ph2_resized])

# %%
X_train[0].shape
# Out:
# (224, 224, 3)

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %%
x_train[0].shape
print(y_train[0].shape)
# Out:
# (224, 224)

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[0])
plt.subplot(2,4,3)
plt.imshow(Y_train[77])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
def dice_coe(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)

# %%
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print(x_train[0].shape)
y_train[0].shape
# Out:
# (224, 224, 3)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
INPUT_CHANNELS = 3
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
# Pretrained weights

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.common.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_224(epochs_num, savename):
    dropout_val=0.50
    if K.common.image_dim_ordering() == 'th':
        inputs = Input((INPUT_CHANNELS, 224, 224))
        axis = 1
    else:
        inputs = Input((224, 224, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224,224))(conv_final)
    model = Model(inputs, pred, name="UNET_224")
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18,validation_data=(x_val, y_val), verbose=1)
    model.save(savename)
    return model, hist

# %%
model, hist = UNET_224(1, 'unet_1_epoch.h5')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Model: "UNET_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 32) 9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 224, 224, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 112, 112, 32) 0           spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 64) 36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 112, 112, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 112, 112, 64) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 64)   0           spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 56, 56, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 128)  0           spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_4 (SpatialDro (None, 28, 28, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 256)  0           spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 512)  2359808     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_5 (SpatialDro (None, 14, 14, 512)  0           activation_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 512)    0           spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 1024)   4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 1024)   4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_6 (SpatialDro (None, 7, 7, 1024)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 14, 14, 1024) 0           spatial_dropout2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 1536) 0           up_sampling2d_1[0][0]
#                                                                  spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 14, 14, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 512)  2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 14, 14, 512)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_7 (SpatialDro (None, 14, 14, 512)  0           activation_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 28, 28, 512)  0           spatial_dropout2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 768)  0           up_sampling2d_2[0][0]
#                                                                  spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 256)  590080      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_8 (SpatialDro (None, 28, 28, 256)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 56, 56, 256)  0           spatial_dropout2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 384)  0           up_sampling2d_3[0][0]
#                                                                  spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 56, 56, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 56, 56, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 56, 56, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 56, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_9 (SpatialDro (None, 56, 56, 128)  0           activation_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 112, 112, 128 0           spatial_dropout2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 112, 112, 192 0           up_sampling2d_4[0][0]
#                                                                  spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 112, 112, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 112, 112, 64) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 112, 112, 64) 36928       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 112, 112, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 112, 112, 64) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10 (SpatialDr (None, 112, 112, 64) 0           activation_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 224, 224, 64) 0           spatial_dropout2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 224, 224, 96) 0           up_sampling2d_5[0][0]
#                                                                  spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 224, 224, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 224, 224, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 224, 224, 32) 9248        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 224, 224, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 224, 224, 32) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_11 (SpatialDr (None, 224, 224, 32) 0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 224, 224, 1)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 224, 224)     0           activation_23[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# Train on 360 samples, validate on 90 samples
# Epoch 1/1
# 360/360 [==============================] - 26s 72ms/step - loss: 0.1722 - iou: 0.8278 - dice_coe: 0.5971 - precision: 0.7258 - recall: 0.6564 - accuracy: 0.7998 - val_loss: 0.4749 - val_iou: 0.5251 - val_dice_coe: 0.4750 - val_precision: 0.3131 - val_recall: 1.0000 - val_accuracy: 0.3131

# %%
dropout_val=0.50
if K.common.image_dim_ordering() == 'th':
    inputs = Input((INPUT_CHANNELS, 224, 224))
    axis = 1
else:
    inputs = Input((224, 224, INPUT_CHANNELS))
    axis = 3
filters = 32

conv_224 = double_conv_layer(inputs, filters)
pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

conv_112 = double_conv_layer(pool_112, 2*filters)
pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

conv_56 = double_conv_layer(pool_56, 4*filters)
pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

conv_28 = double_conv_layer(pool_28, 8*filters)
pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

conv_14 = double_conv_layer(pool_14, 16*filters)
pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

conv_7 = double_conv_layer(pool_7, 32*filters)

up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
up_conv_14 = double_conv_layer(up_14, 16*filters)

up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
up_conv_28 = double_conv_layer(up_28, 8*filters)

up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
up_conv_56 = double_conv_layer(up_56, 4*filters)

up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
up_conv_112 = double_conv_layer(up_112, 2*filters)

up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
conv_final = Activation('sigmoid')(conv_final)
pred = Reshape((224,224))(conv_final)

# %%
model_0 = Model(inputs, pred, name="UNET_224")
model_0.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])

# %%
model_0.load_weights('unet_1_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 4s 11ms/step
# ________________________
# IOU:       |   53.24  |
# Dice Coef: |   48.51  |
# Precision: |   32.37  |
# Recall:    |   100.00  |
# Accuracy:  |   32.37  |
# Loss:      |   46.76  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 2s 46ms/step
# ________________________
# IOU:       |   52.54  |
# Dice Coef: |   47.77  |
# Precision: |   31.55  |
# Recall:    |   100.00  |
# Accuracy:  |   31.55  |
# Loss:      |   47.46  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 10ms/step
# ________________________
# IOU:       |   52.51  |
# Dice Coef: |   47.50  |
# Precision: |   31.31  |
# Recall:    |   100.00  |
# Accuracy:  |   31.31  |
# Loss:      |   47.49  |
# ________________________

# %%
model, hist = UNET_224(epochs_num= 100, savename= 'unet_100_epoch.h5')
# Out:
# Model: "UNET_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 224, 224, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 224, 224, 32) 128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 224, 224, 32) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 224, 224, 32) 9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 224, 224, 32) 128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 224, 224, 32) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_23 (SpatialDr (None, 224, 224, 32) 0           activation_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 112, 112, 32) 0           spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 112, 112, 64) 18496       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 112, 112, 64) 256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 112, 112, 64) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 112, 112, 64) 36928       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 112, 112, 64) 256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 112, 112, 64) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_24 (SpatialDr (None, 112, 112, 64) 0           activation_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 56, 56, 64)   0           spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 56, 56, 128)  73856       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 56, 56, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 56, 56, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 56, 56, 128)  147584      activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 56, 56, 128)  512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 56, 56, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_25 (SpatialDr (None, 56, 56, 128)  0           activation_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 28, 28, 128)  0           spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 28, 28, 256)  295168      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 28, 28, 256)  1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 28, 28, 256)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 28, 28, 256)  590080      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 28, 28, 256)  1024        conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 28, 28, 256)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_26 (SpatialDr (None, 28, 28, 256)  0           activation_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 14, 14, 256)  0           spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 512)  1180160     max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 14, 14, 512)  2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 14, 14, 512)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 14, 14, 512)  2359808     activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 14, 14, 512)  2048        conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 14, 14, 512)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_27 (SpatialDr (None, 14, 14, 512)  0           activation_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 7, 7, 512)    0           spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 7, 7, 1024)   4096        conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 7, 7, 1024)   4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_28 (SpatialDr (None, 7, 7, 1024)   0           activation_58[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 14, 14, 1024) 0           spatial_dropout2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 14, 14, 1536) 0           up_sampling2d_11[0][0]
#                                                                  spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 14, 14, 512)  2048        conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 14, 14, 512)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 14, 14, 512)  2359808     activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 14, 14, 512)  2048        conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 14, 14, 512)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_29 (SpatialDr (None, 14, 14, 512)  0           activation_60[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 28, 28, 512)  0           spatial_dropout2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 768)  0           up_sampling2d_12[0][0]
#                                                                  spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 28, 28, 256)  1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 28, 28, 256)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 28, 28, 256)  590080      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 28, 28, 256)  1024        conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 28, 28, 256)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_30 (SpatialDr (None, 28, 28, 256)  0           activation_62[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 56, 56, 256)  0           spatial_dropout2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 56, 56, 384)  0           up_sampling2d_13[0][0]
#                                                                  spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 56, 56, 128)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 56, 56, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 56, 56, 128)  147584      activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 56, 56, 128)  512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 56, 56, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_31 (SpatialDr (None, 56, 56, 128)  0           activation_64[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 112, 112, 128 0           spatial_dropout2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 112, 112, 192 0           up_sampling2d_14[0][0]
#                                                                  spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 112, 112, 64) 256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 112, 112, 64) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 112, 112, 64) 36928       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 112, 112, 64) 256         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 112, 112, 64) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_32 (SpatialDr (None, 112, 112, 64) 0           activation_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 224, 224, 64) 0           spatial_dropout2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 224, 224, 96) 0           up_sampling2d_15[0][0]
#                                                                  spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 224, 224, 32) 128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 224, 224, 32) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 224, 224, 32) 9248        activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 224, 224, 32) 128         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 224, 224, 32) 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_33 (SpatialDr (None, 224, 224, 32) 0           activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_33[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 224, 224, 1)  0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 224, 224)     0           activation_69[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 14s 40ms/step - loss: 0.1622 - iou: 0.8378 - dice_coe: 0.6191 - precision: 0.7305 - recall: 0.7057 - accuracy: 0.8139 - val_loss: 0.4749 - val_iou: 0.5251 - val_dice_coe: 0.4750 - val_precision: 0.3131 - val_recall: 1.0000 - val_accuracy: 0.3131
# Epoch 2/100
# 360/360 [==============================] - 12s 33ms/step - loss: 0.1031 - iou: 0.8969 - dice_coe: 0.7363 - precision: 0.8359 - recall: 0.8048 - accuracy: 0.8833 - val_loss: 0.4749 - val_iou: 0.5251 - val_dice_coe: 0.4750 - val_precision: 0.3131 - val_recall: 1.0000 - val_accuracy: 0.3131
# Epoch 3/100
# 360/360 [==============================] - 12s 33ms/step - loss: 0.0940 - iou: 0.9060 - dice_coe: 0.7645 - precision: 0.8744 - recall: 0.8005 - accuracy: 0.8960 - val_loss: 0.4749 - val_iou: 0.5251 - val_dice_coe: 0.4750 - val_precision: 0.3131 - val_recall: 1.0000 - val_accuracy: 0.3131
# Epoch 4/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0945 - iou: 0.9055 - dice_coe: 0.7727 - precision: 0.8503 - recall: 0.8143 - accuracy: 0.8918 - val_loss: 0.4749 - val_iou: 0.5251 - val_dice_coe: 0.4750 - val_precision: 0.3131 - val_recall: 1.0000 - val_accuracy: 0.3131
# Epoch 5/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0896 - iou: 0.9104 - dice_coe: 0.7753 - precision: 0.8877 - recall: 0.7961 - accuracy: 0.8990 - val_loss: 0.4722 - val_iou: 0.5278 - val_dice_coe: 0.4767 - val_precision: 0.3147 - val_recall: 0.9990 - val_accuracy: 0.3186
# Epoch 6/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0813 - iou: 0.9187 - dice_coe: 0.7953 - precision: 0.8709 - recall: 0.8438 - accuracy: 0.9070 - val_loss: 0.4004 - val_iou: 0.5996 - val_dice_coe: 0.5228 - val_precision: 0.3564 - val_recall: 0.9873 - val_accuracy: 0.4382
# Epoch 7/100
# 360/360 [==============================] - 13s 35ms/step - loss: 0.0846 - iou: 0.9154 - dice_coe: 0.7939 - precision: 0.8803 - recall: 0.8128 - accuracy: 0.9013 - val_loss: 0.4719 - val_iou: 0.5281 - val_dice_coe: 0.4753 - val_precision: 0.3139 - val_recall: 0.9954 - val_accuracy: 0.3173
# Epoch 8/100
# 360/360 [==============================] - 13s 35ms/step - loss: 0.0799 - iou: 0.9201 - dice_coe: 0.8087 - precision: 0.8802 - recall: 0.8376 - accuracy: 0.9089 - val_loss: 0.4553 - val_iou: 0.5447 - val_dice_coe: 0.4895 - val_precision: 0.3247 - val_recall: 0.9994 - val_accuracy: 0.3485
# Epoch 9/100
# 360/360 [==============================] - 12s 35ms/step - loss: 0.0801 - iou: 0.9199 - dice_coe: 0.8125 - precision: 0.8817 - recall: 0.8327 - accuracy: 0.9075 - val_loss: 0.3451 - val_iou: 0.6549 - val_dice_coe: 0.0286 - val_precision: 0.0678 - val_recall: 0.0122 - val_accuracy: 0.6565
# Epoch 10/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0813 - iou: 0.9187 - dice_coe: 0.8048 - precision: 0.8712 - recall: 0.8372 - accuracy: 0.9043 - val_loss: 0.1922 - val_iou: 0.8078 - val_dice_coe: 0.5977 - val_precision: 0.7704 - val_recall: 0.4836 - val_accuracy: 0.7904
# Epoch 11/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0864 - iou: 0.9136 - dice_coe: 0.7898 - precision: 0.8903 - recall: 0.8068 - accuracy: 0.9003 - val_loss: 0.1727 - val_iou: 0.8273 - val_dice_coe: 0.7179 - val_precision: 0.6304 - val_recall: 0.8857 - val_accuracy: 0.7980
# Epoch 12/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0787 - iou: 0.9213 - dice_coe: 0.8137 - precision: 0.8935 - recall: 0.8176 - accuracy: 0.9079 - val_loss: 0.2943 - val_iou: 0.7057 - val_dice_coe: 0.6200 - val_precision: 0.4599 - val_recall: 0.9789 - val_accuracy: 0.6300
# Epoch 13/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0752 - iou: 0.9248 - dice_coe: 0.8216 - precision: 0.8869 - recall: 0.8457 - accuracy: 0.9130 - val_loss: 0.4516 - val_iou: 0.5484 - val_dice_coe: 0.4926 - val_precision: 0.3277 - val_recall: 0.9999 - val_accuracy: 0.3574
# Epoch 14/100
# 360/360 [==============================] - 12s 35ms/step - loss: 0.0702 - iou: 0.9298 - dice_coe: 0.8279 - precision: 0.9000 - recall: 0.8549 - accuracy: 0.9191 - val_loss: 0.2004 - val_iou: 0.7996 - val_dice_coe: 0.7021 - val_precision: 0.5571 - val_recall: 0.9762 - val_accuracy: 0.7495
# Epoch 15/100
# 360/360 [==============================] - 12s 35ms/step - loss: 0.0690 - iou: 0.9310 - dice_coe: 0.8372 - precision: 0.8911 - recall: 0.8657 - accuracy: 0.9197 - val_loss: 0.1331 - val_iou: 0.8669 - val_dice_coe: 0.7751 - val_precision: 0.6678 - val_recall: 0.9395 - val_accuracy: 0.8357
# Epoch 16/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0683 - iou: 0.9317 - dice_coe: 0.8347 - precision: 0.9161 - recall: 0.8394 - accuracy: 0.9222 - val_loss: 0.3088 - val_iou: 0.6912 - val_dice_coe: 0.5122 - val_precision: 0.4128 - val_recall: 0.6960 - val_accuracy: 0.5951
# Epoch 17/100
# 360/360 [==============================] - 12s 35ms/step - loss: 0.0674 - iou: 0.9326 - dice_coe: 0.8401 - precision: 0.9016 - recall: 0.8639 - accuracy: 0.9234 - val_loss: 0.1255 - val_iou: 0.8745 - val_dice_coe: 0.7961 - val_precision: 0.7083 - val_recall: 0.9235 - val_accuracy: 0.8570
# Epoch 18/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0660 - iou: 0.9340 - dice_coe: 0.8378 - precision: 0.9131 - recall: 0.8479 - accuracy: 0.9230 - val_loss: 0.2108 - val_iou: 0.7892 - val_dice_coe: 0.6789 - val_precision: 0.5513 - val_recall: 0.8909 - val_accuracy: 0.7376
# Epoch 19/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0642 - iou: 0.9358 - dice_coe: 0.8486 - precision: 0.9124 - recall: 0.8656 - accuracy: 0.9277 - val_loss: 0.0776 - val_iou: 0.9224 - val_dice_coe: 0.8422 - val_precision: 0.9194 - val_recall: 0.7975 - val_accuracy: 0.9163
# Epoch 20/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0646 - iou: 0.9354 - dice_coe: 0.8499 - precision: 0.9051 - recall: 0.8653 - accuracy: 0.9258 - val_loss: 0.1202 - val_iou: 0.8798 - val_dice_coe: 0.8005 - val_precision: 0.7063 - val_recall: 0.9431 - val_accuracy: 0.8603
# Epoch 21/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0652 - iou: 0.9348 - dice_coe: 0.8420 - precision: 0.9142 - recall: 0.8529 - accuracy: 0.9237 - val_loss: 0.0894 - val_iou: 0.9106 - val_dice_coe: 0.8326 - val_precision: 0.8849 - val_recall: 0.8124 - val_accuracy: 0.9071
# Epoch 22/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0682 - iou: 0.9318 - dice_coe: 0.8356 - precision: 0.9158 - recall: 0.8437 - accuracy: 0.9232 - val_loss: 0.3310 - val_iou: 0.6690 - val_dice_coe: 0.5799 - val_precision: 0.4074 - val_recall: 0.9889 - val_accuracy: 0.5445
# Epoch 23/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0602 - iou: 0.9398 - dice_coe: 0.8576 - precision: 0.9165 - recall: 0.8751 - accuracy: 0.9315 - val_loss: 0.0815 - val_iou: 0.9185 - val_dice_coe: 0.8234 - val_precision: 0.9626 - val_recall: 0.7349 - val_accuracy: 0.9061
# Epoch 24/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0584 - iou: 0.9416 - dice_coe: 0.8580 - precision: 0.9212 - recall: 0.8734 - accuracy: 0.9332 - val_loss: 0.0612 - val_iou: 0.9388 - val_dice_coe: 0.8694 - val_precision: 0.9562 - val_recall: 0.8145 - val_accuracy: 0.9287
# Epoch 25/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0568 - iou: 0.9432 - dice_coe: 0.8629 - precision: 0.9268 - recall: 0.8729 - accuracy: 0.9355 - val_loss: 0.0673 - val_iou: 0.9327 - val_dice_coe: 0.8664 - val_precision: 0.9086 - val_recall: 0.8413 - val_accuracy: 0.9238
# Epoch 26/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0592 - iou: 0.9408 - dice_coe: 0.8593 - precision: 0.9205 - recall: 0.8728 - accuracy: 0.9327 - val_loss: 0.0646 - val_iou: 0.9354 - val_dice_coe: 0.8706 - val_precision: 0.8877 - val_recall: 0.9066 - val_accuracy: 0.9334
# Epoch 27/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0597 - iou: 0.9403 - dice_coe: 0.8642 - precision: 0.9072 - recall: 0.8843 - accuracy: 0.9312 - val_loss: 0.0677 - val_iou: 0.9323 - val_dice_coe: 0.8597 - val_precision: 0.8715 - val_recall: 0.9072 - val_accuracy: 0.9292
# Epoch 28/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0637 - iou: 0.9363 - dice_coe: 0.8479 - precision: 0.9206 - recall: 0.8555 - accuracy: 0.9275 - val_loss: 0.0659 - val_iou: 0.9341 - val_dice_coe: 0.8656 - val_precision: 0.9251 - val_recall: 0.8342 - val_accuracy: 0.9269
# Epoch 29/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0631 - iou: 0.9369 - dice_coe: 0.8557 - precision: 0.9194 - recall: 0.8630 - accuracy: 0.9288 - val_loss: 0.0808 - val_iou: 0.9192 - val_dice_coe: 0.8501 - val_precision: 0.8071 - val_recall: 0.9191 - val_accuracy: 0.9056
# Epoch 30/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0559 - iou: 0.9441 - dice_coe: 0.8661 - precision: 0.9181 - recall: 0.8870 - accuracy: 0.9367 - val_loss: 0.0547 - val_iou: 0.9453 - val_dice_coe: 0.8929 - val_precision: 0.9105 - val_recall: 0.8976 - val_accuracy: 0.9390
# Epoch 31/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0575 - iou: 0.9425 - dice_coe: 0.8614 - precision: 0.9275 - recall: 0.8697 - accuracy: 0.9349 - val_loss: 0.0505 - val_iou: 0.9495 - val_dice_coe: 0.8925 - val_precision: 0.9356 - val_recall: 0.8770 - val_accuracy: 0.9416
# Epoch 32/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0572 - iou: 0.9428 - dice_coe: 0.8679 - precision: 0.9229 - recall: 0.8812 - accuracy: 0.9358 - val_loss: 0.0523 - val_iou: 0.9477 - val_dice_coe: 0.8881 - val_precision: 0.9502 - val_recall: 0.8499 - val_accuracy: 0.9384
# Epoch 33/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0602 - iou: 0.9398 - dice_coe: 0.8576 - precision: 0.9190 - recall: 0.8690 - accuracy: 0.9309 - val_loss: 0.0460 - val_iou: 0.9540 - val_dice_coe: 0.8984 - val_precision: 0.9475 - val_recall: 0.8765 - val_accuracy: 0.9450
# Epoch 34/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0603 - iou: 0.9397 - dice_coe: 0.8554 - precision: 0.9075 - recall: 0.8763 - accuracy: 0.9294 - val_loss: 0.0674 - val_iou: 0.9326 - val_dice_coe: 0.8570 - val_precision: 0.8848 - val_recall: 0.8857 - val_accuracy: 0.9247
# Epoch 35/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0592 - iou: 0.9408 - dice_coe: 0.8563 - precision: 0.9193 - recall: 0.8748 - accuracy: 0.9320 - val_loss: 0.0621 - val_iou: 0.9379 - val_dice_coe: 0.8694 - val_precision: 0.8648 - val_recall: 0.9297 - val_accuracy: 0.9309
# Epoch 36/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0544 - iou: 0.9456 - dice_coe: 0.8723 - precision: 0.9270 - recall: 0.8804 - accuracy: 0.9372 - val_loss: 0.0557 - val_iou: 0.9443 - val_dice_coe: 0.8808 - val_precision: 0.9165 - val_recall: 0.8705 - val_accuracy: 0.9341
# Epoch 37/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0530 - iou: 0.9470 - dice_coe: 0.8743 - precision: 0.9308 - recall: 0.8812 - accuracy: 0.9393 - val_loss: 0.0926 - val_iou: 0.9074 - val_dice_coe: 0.8327 - val_precision: 0.7753 - val_recall: 0.9378 - val_accuracy: 0.8918
# Epoch 38/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0508 - iou: 0.9492 - dice_coe: 0.8766 - precision: 0.9320 - recall: 0.8928 - accuracy: 0.9434 - val_loss: 0.2049 - val_iou: 0.7951 - val_dice_coe: 0.7007 - val_precision: 0.5527 - val_recall: 0.9927 - val_accuracy: 0.7467
# Epoch 39/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0543 - iou: 0.9457 - dice_coe: 0.8731 - precision: 0.9303 - recall: 0.8819 - accuracy: 0.9376 - val_loss: 0.0852 - val_iou: 0.9148 - val_dice_coe: 0.8356 - val_precision: 0.8292 - val_recall: 0.8568 - val_accuracy: 0.8998
# Epoch 40/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0538 - iou: 0.9462 - dice_coe: 0.8745 - precision: 0.9216 - recall: 0.8858 - accuracy: 0.9376 - val_loss: 0.2302 - val_iou: 0.7698 - val_dice_coe: 0.6680 - val_precision: 0.5083 - val_recall: 0.9910 - val_accuracy: 0.6979
# Epoch 41/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0498 - iou: 0.9502 - dice_coe: 0.8809 - precision: 0.9303 - recall: 0.8928 - accuracy: 0.9432 - val_loss: 0.0618 - val_iou: 0.9382 - val_dice_coe: 0.8629 - val_precision: 0.8789 - val_recall: 0.8834 - val_accuracy: 0.9252
# Epoch 42/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0520 - iou: 0.9480 - dice_coe: 0.8768 - precision: 0.9409 - recall: 0.8783 - accuracy: 0.9408 - val_loss: 0.0669 - val_iou: 0.9331 - val_dice_coe: 0.8615 - val_precision: 0.8542 - val_recall: 0.8882 - val_accuracy: 0.9176
# Epoch 43/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0583 - iou: 0.9417 - dice_coe: 0.8665 - precision: 0.9152 - recall: 0.8823 - accuracy: 0.9332 - val_loss: 0.0711 - val_iou: 0.9289 - val_dice_coe: 0.8560 - val_precision: 0.9244 - val_recall: 0.8192 - val_accuracy: 0.9186
# Epoch 44/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0555 - iou: 0.9445 - dice_coe: 0.8705 - precision: 0.9352 - recall: 0.8688 - accuracy: 0.9357 - val_loss: 0.0451 - val_iou: 0.9549 - val_dice_coe: 0.9039 - val_precision: 0.8796 - val_recall: 0.9559 - val_accuracy: 0.9460
# Epoch 45/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0549 - iou: 0.9451 - dice_coe: 0.8703 - precision: 0.9232 - recall: 0.8841 - accuracy: 0.9364 - val_loss: 0.0604 - val_iou: 0.9396 - val_dice_coe: 0.8792 - val_precision: 0.8522 - val_recall: 0.9518 - val_accuracy: 0.9325
# Epoch 46/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0520 - iou: 0.9480 - dice_coe: 0.8784 - precision: 0.9239 - recall: 0.8968 - accuracy: 0.9409 - val_loss: 0.0643 - val_iou: 0.9357 - val_dice_coe: 0.8706 - val_precision: 0.8595 - val_recall: 0.9234 - val_accuracy: 0.9264
# Epoch 47/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0480 - iou: 0.9520 - dice_coe: 0.8854 - precision: 0.9318 - recall: 0.8974 - accuracy: 0.9446 - val_loss: 0.0606 - val_iou: 0.9394 - val_dice_coe: 0.8704 - val_precision: 0.8776 - val_recall: 0.9223 - val_accuracy: 0.9332
# Epoch 48/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0483 - iou: 0.9517 - dice_coe: 0.8853 - precision: 0.9312 - recall: 0.8981 - accuracy: 0.9444 - val_loss: 0.0420 - val_iou: 0.9580 - val_dice_coe: 0.9074 - val_precision: 0.9133 - val_recall: 0.9366 - val_accuracy: 0.9510
# Epoch 49/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0504 - iou: 0.9496 - dice_coe: 0.8837 - precision: 0.9329 - recall: 0.8946 - accuracy: 0.9426 - val_loss: 0.0755 - val_iou: 0.9245 - val_dice_coe: 0.8636 - val_precision: 0.7988 - val_recall: 0.9626 - val_accuracy: 0.9124
# Epoch 50/100
# 360/360 [==============================] - 12s 35ms/step - loss: 0.0481 - iou: 0.9519 - dice_coe: 0.8861 - precision: 0.9335 - recall: 0.8976 - accuracy: 0.9448 - val_loss: 0.0370 - val_iou: 0.9630 - val_dice_coe: 0.9172 - val_precision: 0.9388 - val_recall: 0.9223 - val_accuracy: 0.9567
# Epoch 51/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0487 - iou: 0.9513 - dice_coe: 0.8883 - precision: 0.9349 - recall: 0.8960 - accuracy: 0.9446 - val_loss: 0.0504 - val_iou: 0.9496 - val_dice_coe: 0.8912 - val_precision: 0.8986 - val_recall: 0.9168 - val_accuracy: 0.9417
# Epoch 52/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0540 - iou: 0.9460 - dice_coe: 0.8741 - precision: 0.9346 - recall: 0.8792 - accuracy: 0.9377 - val_loss: 0.0512 - val_iou: 0.9488 - val_dice_coe: 0.8747 - val_precision: 0.9605 - val_recall: 0.8254 - val_accuracy: 0.9338
# Epoch 53/100
# 360/360 [==============================] - 12s 35ms/step - loss: 0.0489 - iou: 0.9511 - dice_coe: 0.8830 - precision: 0.9318 - recall: 0.8964 - accuracy: 0.9441 - val_loss: 0.0444 - val_iou: 0.9556 - val_dice_coe: 0.8875 - val_precision: 0.9591 - val_recall: 0.8678 - val_accuracy: 0.9459
# Epoch 54/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0450 - iou: 0.9550 - dice_coe: 0.8931 - precision: 0.9377 - recall: 0.9060 - accuracy: 0.9495 - val_loss: 0.0531 - val_iou: 0.9469 - val_dice_coe: 0.8882 - val_precision: 0.9020 - val_recall: 0.9150 - val_accuracy: 0.9406
# Epoch 55/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0450 - iou: 0.9550 - dice_coe: 0.8976 - precision: 0.9423 - recall: 0.8977 - accuracy: 0.9485 - val_loss: 0.0457 - val_iou: 0.9543 - val_dice_coe: 0.9059 - val_precision: 0.8945 - val_recall: 0.9420 - val_accuracy: 0.9477
# Epoch 56/100
# 360/360 [==============================] - 12s 35ms/step - loss: 0.0467 - iou: 0.9533 - dice_coe: 0.8881 - precision: 0.9291 - recall: 0.9085 - accuracy: 0.9470 - val_loss: 0.0408 - val_iou: 0.9592 - val_dice_coe: 0.9071 - val_precision: 0.9206 - val_recall: 0.9326 - val_accuracy: 0.9519
# Epoch 57/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0445 - iou: 0.9555 - dice_coe: 0.8942 - precision: 0.9405 - recall: 0.9044 - accuracy: 0.9493 - val_loss: 0.0549 - val_iou: 0.9451 - val_dice_coe: 0.8729 - val_precision: 0.9800 - val_recall: 0.8087 - val_accuracy: 0.9323
# Epoch 58/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0482 - iou: 0.9518 - dice_coe: 0.8891 - precision: 0.9315 - recall: 0.8991 - accuracy: 0.9452 - val_loss: 0.0466 - val_iou: 0.9534 - val_dice_coe: 0.8821 - val_precision: 0.9613 - val_recall: 0.8477 - val_accuracy: 0.9397
# Epoch 59/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0528 - iou: 0.9472 - dice_coe: 0.8760 - precision: 0.9452 - recall: 0.8682 - accuracy: 0.9387 - val_loss: 0.0459 - val_iou: 0.9541 - val_dice_coe: 0.8846 - val_precision: 0.9490 - val_recall: 0.8757 - val_accuracy: 0.9446
# Epoch 60/100
# 360/360 [==============================] - 12s 35ms/step - loss: 0.0463 - iou: 0.9537 - dice_coe: 0.8926 - precision: 0.9354 - recall: 0.9045 - accuracy: 0.9480 - val_loss: 0.0378 - val_iou: 0.9622 - val_dice_coe: 0.9039 - val_precision: 0.9685 - val_recall: 0.8830 - val_accuracy: 0.9532
# Epoch 61/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0476 - iou: 0.9524 - dice_coe: 0.8893 - precision: 0.9304 - recall: 0.9057 - accuracy: 0.9454 - val_loss: 0.0362 - val_iou: 0.9638 - val_dice_coe: 0.9137 - val_precision: 0.9412 - val_recall: 0.9313 - val_accuracy: 0.9592
# Epoch 62/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0454 - iou: 0.9546 - dice_coe: 0.8882 - precision: 0.9383 - recall: 0.9036 - accuracy: 0.9486 - val_loss: 0.0494 - val_iou: 0.9506 - val_dice_coe: 0.8878 - val_precision: 0.8915 - val_recall: 0.9469 - val_accuracy: 0.9458
# Epoch 63/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0458 - iou: 0.9542 - dice_coe: 0.8960 - precision: 0.9379 - recall: 0.9041 - accuracy: 0.9484 - val_loss: 0.0344 - val_iou: 0.9656 - val_dice_coe: 0.9216 - val_precision: 0.9318 - val_recall: 0.9432 - val_accuracy: 0.9601
# Epoch 64/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0435 - iou: 0.9565 - dice_coe: 0.8979 - precision: 0.9389 - recall: 0.9065 - accuracy: 0.9500 - val_loss: 0.0488 - val_iou: 0.9512 - val_dice_coe: 0.8997 - val_precision: 0.8650 - val_recall: 0.9730 - val_accuracy: 0.9446
# Epoch 65/100
# 360/360 [==============================] - 12s 35ms/step - loss: 0.0453 - iou: 0.9547 - dice_coe: 0.8931 - precision: 0.9417 - recall: 0.8982 - accuracy: 0.9484 - val_loss: 0.0416 - val_iou: 0.9584 - val_dice_coe: 0.9098 - val_precision: 0.9165 - val_recall: 0.9401 - val_accuracy: 0.9534
# Epoch 66/100
# 360/360 [==============================] - 12s 35ms/step - loss: 0.0483 - iou: 0.9517 - dice_coe: 0.8887 - precision: 0.9284 - recall: 0.9048 - accuracy: 0.9449 - val_loss: 0.0446 - val_iou: 0.9554 - val_dice_coe: 0.8957 - val_precision: 0.9694 - val_recall: 0.8568 - val_accuracy: 0.9451
# Epoch 67/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0457 - iou: 0.9543 - dice_coe: 0.8939 - precision: 0.9337 - recall: 0.9069 - accuracy: 0.9480 - val_loss: 0.0484 - val_iou: 0.9516 - val_dice_coe: 0.8949 - val_precision: 0.9171 - val_recall: 0.9144 - val_accuracy: 0.9454
# Epoch 68/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0477 - iou: 0.9523 - dice_coe: 0.8908 - precision: 0.9313 - recall: 0.9019 - accuracy: 0.9458 - val_loss: 0.0470 - val_iou: 0.9530 - val_dice_coe: 0.8994 - val_precision: 0.9133 - val_recall: 0.9029 - val_accuracy: 0.9435
# Epoch 69/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0463 - iou: 0.9537 - dice_coe: 0.8907 - precision: 0.9447 - recall: 0.8942 - accuracy: 0.9468 - val_loss: 0.0612 - val_iou: 0.9388 - val_dice_coe: 0.8749 - val_precision: 0.8385 - val_recall: 0.9687 - val_accuracy: 0.9312
# Epoch 70/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0427 - iou: 0.9573 - dice_coe: 0.9000 - precision: 0.9365 - recall: 0.9173 - accuracy: 0.9521 - val_loss: 0.0376 - val_iou: 0.9624 - val_dice_coe: 0.9202 - val_precision: 0.9076 - val_recall: 0.9583 - val_accuracy: 0.9563
# Epoch 71/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0469 - iou: 0.9531 - dice_coe: 0.8938 - precision: 0.9296 - recall: 0.9049 - accuracy: 0.9463 - val_loss: 0.0349 - val_iou: 0.9651 - val_dice_coe: 0.9197 - val_precision: 0.9198 - val_recall: 0.9532 - val_accuracy: 0.9588
# Epoch 72/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0419 - iou: 0.9581 - dice_coe: 0.8983 - precision: 0.9406 - recall: 0.9133 - accuracy: 0.9522 - val_loss: 0.0353 - val_iou: 0.9647 - val_dice_coe: 0.9191 - val_precision: 0.9194 - val_recall: 0.9579 - val_accuracy: 0.9597
# Epoch 73/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0476 - iou: 0.9524 - dice_coe: 0.8880 - precision: 0.9304 - recall: 0.9016 - accuracy: 0.9453 - val_loss: 0.0391 - val_iou: 0.9609 - val_dice_coe: 0.9114 - val_precision: 0.9235 - val_recall: 0.9445 - val_accuracy: 0.9572
# Epoch 74/100
# 360/360 [==============================] - 12s 34ms/step - loss: 0.0449 - iou: 0.9551 - dice_coe: 0.8935 - precision: 0.9498 - recall: 0.8920 - accuracy: 0.9474 - val_loss: 0.0461 - val_iou: 0.9539 - val_dice_coe: 0.8878 - val_precision: 0.9391 - val_recall: 0.8981 - val_accuracy: 0.9478
# Epoch 75/100
# 234/360 [==================>...........] - ETA: 4s - loss: 0.0420 - iou: 0.9580 - dice_coe: 0.9005 - precision: 0.9328 - recall: 0.9194 - accuracy: 0.9514
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-163739627ed5> in <module>()
# ----> 1 model, hist = UNET_224(epochs_num= 100, savename= 'unet_100_epoch.h5')
#
# <ipython-input-28-d7f3cd3aa1fb> in UNET_224(epochs_num, savename)
#      66                   , metrics=[iou, dice_coe, precision, recall, accuracy])
#      67     model.summary()
# ---> 68     hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18,validation_data=(x_val, y_val), verbose=1)
#      69     model.save(savename)
#      70     return model, hist
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model_1 = Model(inputs, pred, name="UNET_224")
model_1.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])

# %%
model_1.load_weights('unet_100_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,224,224,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.show()
