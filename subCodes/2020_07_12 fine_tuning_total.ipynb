# %%
# %tensorflow_version 1.x
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from keras.optimizers import Adam
import keras
from keras.models import load_model
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
np.random.seed(101)

import re
numbers = re.compile(r'(\d+)')
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts
    
def resizeX(filename, size = (224,224)):
    im = Image.open(filename)
    im_resized = im.resize(size)
    return (im_resized)

def resizeY(filename, size = (224,224)):
    im = Image.open(filename)
    im_resized = im.resize(size).convert('1')
    return (im_resized)

def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def dice_coe(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.common.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_224(epochs_num, savename, x_train, y_train, x_val, y_val, learningRate = 0.003):
    dropout_val=0.50
    if K.common.image_dim_ordering() == 'th':
        inputs = Input((INPUT_CHANNELS, 224, 224))
        axis = 1
    else:
        inputs = Input((224, 224, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224,224))(conv_final)
    model = load_model('/content/drive/My Drive/models/pre_100_epoch.h5' ,custom_objects = {'iou' : iou, 'dice_coe' : dice_coe, 'precision' : precision, 'recall' : recall, 'accuracy' : accuracy, 'jaccard_distance' : jaccard_distance})
    # model = load_model('/content/drive/My Drive/models/pre_100_epoch.h5')
    # model = Model(inputs, pred, name="UNET_224")
    model.compile(optimizer= Adam(lr = learningRate), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 3,validation_data=(x_val, y_val), verbose=1)
    model.save(savename)
    return model, hist

def enhance(img, filename):
    model.load_weights('/content/drive/My Drive/models/' + filename)
    sub = (model.predict(img.reshape(1,224,224,3))).flatten()

    # for i in range(len(sub)):
    #     if sub[i] <= 0.165:
    #         sub[i] = 0
    #     elif sub[i] <= 0.97:
    #         sub[i] = 1
    #     else:
    #         sub[i] = 2
    return sub

# %%
X_train_ph2_resized = []
Y_train_ph2_resized = []
X_test_ph2_resized = []
Y_test_ph2_resized = []

# %%
filelist_trainx = sorted(glob.glob('/content/drive/My Drive/input/trainX_total/*.jpg'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

for i in range(len(filelist_trainx)):
    X_train_ph2_resized.append(resizeX(filelist_trainx[i]))

print(len(filelist_trainx))

del(X_train)
del(filelist_trainx)

x_train = np.array([np.array(img) for img in X_train_ph2_resized])

del(X_train_ph2_resized)
# Out:
# 164

# %%
filelist_trainy = sorted(glob.glob('/content/drive/My Drive/input/trainY_total/*.jpg'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

for i in range(len(filelist_trainy)):
    Y_train_ph2_resized.append(resizeY(filelist_trainy[i]))

print(len(filelist_trainy))


del(Y_train)
del(filelist_trainy)

y_train = np.array([np.array(img) for img in Y_train_ph2_resized])

del(Y_train_ph2_resized)
# Out:
# 164

# %%
filelist_testX = sorted(glob.glob('/content/drive/My Drive/input/testX_notWater/*.jpg'), key=numericalSort)
x_test = np.array([np.array(Image.open(fname)) for fname in filelist_testX])

# %%
filelist_testY = sorted(glob.glob('/content/drive/My Drive/input/testY/*.jpg'), key=numericalSort)
y_test = np.array([np.array(Image.open(fname)) for fname in filelist_testY])

# %%
for i in range(len(filelist_testX)):
    X_test_ph2_resized.append(resizeX(filelist_testX[i]))
    Y_test_ph2_resized.append(resizeY(filelist_testY[i]))

# %%
del(x_test)
del(y_test)

x_test = np.array([np.array(img) for img in X_test_ph2_resized])
y_test = np.array([np.array(img) for img in Y_test_ph2_resized])

# x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)

x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 787
# Length of the Test Set       : 20
# Length of the Validation Set : 197

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
INPUT_CHANNELS = 3
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
# Pretrained weights

# iou, dice_coe, precision, recall, accuracy
# callback_list =[ keras.callbacks.ModelCheckpoint( filepath = '/content/drive/My Drive/models/pre_100_epoch.h5',monitor = 'val_loss',save_best_only=True )]


model, hist = UNET_224(100, '/content/drive/My Drive/models/20200712_total_100_epoch.h5', x_train, y_train, x_val, y_val, 0.0003)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Model: "UNET_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 224, 224, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 224, 224, 32) 128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 224, 224, 32) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 224, 224, 32) 9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 224, 224, 32) 128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 224, 224, 32) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_23 (SpatialDr (None, 224, 224, 32) 0           activation_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 112, 112, 32) 0           spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 112, 112, 64) 18496       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 112, 112, 64) 256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 112, 112, 64) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 112, 112, 64) 36928       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 112, 112, 64) 256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 112, 112, 64) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_24 (SpatialDr (None, 112, 112, 64) 0           activation_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 56, 56, 64)   0           spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 56, 56, 128)  73856       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 56, 56, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 56, 56, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 56, 56, 128)  147584      activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 56, 56, 128)  512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 56, 56, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_25 (SpatialDr (None, 56, 56, 128)  0           activation_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 28, 28, 128)  0           spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 28, 28, 256)  295168      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 28, 28, 256)  1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 28, 28, 256)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 28, 28, 256)  590080      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 28, 28, 256)  1024        conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 28, 28, 256)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_26 (SpatialDr (None, 28, 28, 256)  0           activation_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 14, 14, 256)  0           spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 512)  1180160     max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 14, 14, 512)  2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 14, 14, 512)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 14, 14, 512)  2359808     activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 14, 14, 512)  2048        conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 14, 14, 512)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_27 (SpatialDr (None, 14, 14, 512)  0           activation_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 7, 7, 512)    0           spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 7, 7, 1024)   4096        conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 7, 7, 1024)   4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_28 (SpatialDr (None, 7, 7, 1024)   0           activation_58[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 14, 14, 1024) 0           spatial_dropout2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 14, 14, 1536) 0           up_sampling2d_11[0][0]
#                                                                  spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 14, 14, 512)  2048        conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 14, 14, 512)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 14, 14, 512)  2359808     activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 14, 14, 512)  2048        conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 14, 14, 512)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_29 (SpatialDr (None, 14, 14, 512)  0           activation_60[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 28, 28, 512)  0           spatial_dropout2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 768)  0           up_sampling2d_12[0][0]
#                                                                  spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 28, 28, 256)  1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 28, 28, 256)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 28, 28, 256)  590080      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 28, 28, 256)  1024        conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 28, 28, 256)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_30 (SpatialDr (None, 28, 28, 256)  0           activation_62[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 56, 56, 256)  0           spatial_dropout2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 56, 56, 384)  0           up_sampling2d_13[0][0]
#                                                                  spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 56, 56, 128)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 56, 56, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 56, 56, 128)  147584      activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 56, 56, 128)  512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 56, 56, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_31 (SpatialDr (None, 56, 56, 128)  0           activation_64[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 112, 112, 128 0           spatial_dropout2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 112, 112, 192 0           up_sampling2d_14[0][0]
#                                                                  spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 112, 112, 64) 256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 112, 112, 64) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 112, 112, 64) 36928       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 112, 112, 64) 256         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 112, 112, 64) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_32 (SpatialDr (None, 112, 112, 64) 0           activation_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 224, 224, 64) 0           spatial_dropout2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 224, 224, 96) 0           up_sampling2d_15[0][0]
#                                                                  spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 224, 224, 32) 128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 224, 224, 32) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 224, 224, 32) 9248        activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 224, 224, 32) 128         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 224, 224, 32) 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_33 (SpatialDr (None, 224, 224, 32) 0           activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_33[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 224, 224, 1)  0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 224, 224)     0           activation_69[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 787 samples, validate on 197 samples
# Epoch 1/100
# 787/787 [==============================] - 33s 42ms/step - loss: 0.0765 - iou: 0.9235 - dice_coe: 0.4625 - precision: 0.6746 - recall: 0.4073 - accuracy: 0.9393 - val_loss: 0.0436 - val_iou: 0.9564 - val_dice_coe: 0.7280 - val_precision: 0.7727 - val_recall: 0.7365 - val_accuracy: 0.9658
# Epoch 2/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0587 - iou: 0.9413 - dice_coe: 0.6235 - precision: 0.7533 - recall: 0.5977 - accuracy: 0.9536 - val_loss: 0.0354 - val_iou: 0.9646 - val_dice_coe: 0.7794 - val_precision: 0.8304 - val_recall: 0.7739 - val_accuracy: 0.9724
# Epoch 3/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0490 - iou: 0.9510 - dice_coe: 0.6922 - precision: 0.7882 - recall: 0.6727 - accuracy: 0.9614 - val_loss: 0.0310 - val_iou: 0.9690 - val_dice_coe: 0.8041 - val_precision: 0.8602 - val_recall: 0.7888 - val_accuracy: 0.9757
# Epoch 4/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0442 - iou: 0.9558 - dice_coe: 0.7245 - precision: 0.8017 - recall: 0.7278 - accuracy: 0.9648 - val_loss: 0.0277 - val_iou: 0.9723 - val_dice_coe: 0.8232 - val_precision: 0.8690 - val_recall: 0.8146 - val_accuracy: 0.9780
# Epoch 5/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0386 - iou: 0.9614 - dice_coe: 0.7637 - precision: 0.8325 - recall: 0.7612 - accuracy: 0.9691 - val_loss: 0.0259 - val_iou: 0.9741 - val_dice_coe: 0.8330 - val_precision: 0.8722 - val_recall: 0.8317 - val_accuracy: 0.9793
# Epoch 6/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0356 - iou: 0.9644 - dice_coe: 0.7767 - precision: 0.8467 - recall: 0.7753 - accuracy: 0.9716 - val_loss: 0.0238 - val_iou: 0.9762 - val_dice_coe: 0.8433 - val_precision: 0.8821 - val_recall: 0.8420 - val_accuracy: 0.9808
# Epoch 7/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0346 - iou: 0.9654 - dice_coe: 0.7788 - precision: 0.8488 - recall: 0.7834 - accuracy: 0.9721 - val_loss: 0.0221 - val_iou: 0.9779 - val_dice_coe: 0.8507 - val_precision: 0.8939 - val_recall: 0.8476 - val_accuracy: 0.9820
# Epoch 8/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0302 - iou: 0.9698 - dice_coe: 0.8013 - precision: 0.8618 - recall: 0.8135 - accuracy: 0.9755 - val_loss: 0.0208 - val_iou: 0.9792 - val_dice_coe: 0.8554 - val_precision: 0.8877 - val_recall: 0.8647 - val_accuracy: 0.9828
# Epoch 9/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0310 - iou: 0.9690 - dice_coe: 0.7919 - precision: 0.8537 - recall: 0.8121 - accuracy: 0.9748 - val_loss: 0.0204 - val_iou: 0.9796 - val_dice_coe: 0.8567 - val_precision: 0.8989 - val_recall: 0.8597 - val_accuracy: 0.9832
# Epoch 10/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0299 - iou: 0.9701 - dice_coe: 0.8002 - precision: 0.8518 - recall: 0.8314 - accuracy: 0.9753 - val_loss: 0.0188 - val_iou: 0.9812 - val_dice_coe: 0.8625 - val_precision: 0.9010 - val_recall: 0.8732 - val_accuracy: 0.9844
# Epoch 11/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0265 - iou: 0.9735 - dice_coe: 0.8193 - precision: 0.8795 - recall: 0.8382 - accuracy: 0.9784 - val_loss: 0.0181 - val_iou: 0.9819 - val_dice_coe: 0.8674 - val_precision: 0.9051 - val_recall: 0.8777 - val_accuracy: 0.9851
# Epoch 12/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0279 - iou: 0.9721 - dice_coe: 0.8028 - precision: 0.8582 - recall: 0.8395 - accuracy: 0.9772 - val_loss: 0.0175 - val_iou: 0.9825 - val_dice_coe: 0.8705 - val_precision: 0.9042 - val_recall: 0.8821 - val_accuracy: 0.9855
# Epoch 13/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0251 - iou: 0.9749 - dice_coe: 0.8283 - precision: 0.8804 - recall: 0.8492 - accuracy: 0.9795 - val_loss: 0.0170 - val_iou: 0.9830 - val_dice_coe: 0.8743 - val_precision: 0.9092 - val_recall: 0.8860 - val_accuracy: 0.9860
# Epoch 14/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0253 - iou: 0.9747 - dice_coe: 0.8278 - precision: 0.8698 - recall: 0.8608 - accuracy: 0.9792 - val_loss: 0.0166 - val_iou: 0.9834 - val_dice_coe: 0.8770 - val_precision: 0.9150 - val_recall: 0.8857 - val_accuracy: 0.9863
# Epoch 15/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0234 - iou: 0.9766 - dice_coe: 0.8330 - precision: 0.8829 - recall: 0.8655 - accuracy: 0.9810 - val_loss: 0.0161 - val_iou: 0.9839 - val_dice_coe: 0.8783 - val_precision: 0.9165 - val_recall: 0.8883 - val_accuracy: 0.9867
# Epoch 16/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0240 - iou: 0.9760 - dice_coe: 0.8301 - precision: 0.8779 - recall: 0.8586 - accuracy: 0.9803 - val_loss: 0.0156 - val_iou: 0.9844 - val_dice_coe: 0.8815 - val_precision: 0.9087 - val_recall: 0.9011 - val_accuracy: 0.9872
# Epoch 17/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0226 - iou: 0.9774 - dice_coe: 0.8384 - precision: 0.8798 - recall: 0.8721 - accuracy: 0.9813 - val_loss: 0.0155 - val_iou: 0.9845 - val_dice_coe: 0.8814 - val_precision: 0.8993 - val_recall: 0.9058 - val_accuracy: 0.9872
# Epoch 18/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0221 - iou: 0.9779 - dice_coe: 0.8416 - precision: 0.8828 - recall: 0.8769 - accuracy: 0.9819 - val_loss: 0.0150 - val_iou: 0.9850 - val_dice_coe: 0.8857 - val_precision: 0.9198 - val_recall: 0.8985 - val_accuracy: 0.9878
# Epoch 19/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0214 - iou: 0.9786 - dice_coe: 0.8419 - precision: 0.8833 - recall: 0.8777 - accuracy: 0.9825 - val_loss: 0.0146 - val_iou: 0.9854 - val_dice_coe: 0.8881 - val_precision: 0.9152 - val_recall: 0.9059 - val_accuracy: 0.9880
# Epoch 20/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0213 - iou: 0.9787 - dice_coe: 0.8460 - precision: 0.8863 - recall: 0.8786 - accuracy: 0.9825 - val_loss: 0.0144 - val_iou: 0.9856 - val_dice_coe: 0.8897 - val_precision: 0.9226 - val_recall: 0.9015 - val_accuracy: 0.9883
# Epoch 21/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0204 - iou: 0.9796 - dice_coe: 0.8538 - precision: 0.8890 - recall: 0.8896 - accuracy: 0.9832 - val_loss: 0.0142 - val_iou: 0.9858 - val_dice_coe: 0.8912 - val_precision: 0.9198 - val_recall: 0.9052 - val_accuracy: 0.9885
# Epoch 22/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0204 - iou: 0.9796 - dice_coe: 0.8504 - precision: 0.8874 - recall: 0.8874 - accuracy: 0.9834 - val_loss: 0.0140 - val_iou: 0.9860 - val_dice_coe: 0.8927 - val_precision: 0.9246 - val_recall: 0.9031 - val_accuracy: 0.9887
# Epoch 23/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0192 - iou: 0.9808 - dice_coe: 0.8585 - precision: 0.8962 - recall: 0.8905 - accuracy: 0.9845 - val_loss: 0.0138 - val_iou: 0.9862 - val_dice_coe: 0.8941 - val_precision: 0.9204 - val_recall: 0.9080 - val_accuracy: 0.9887
# Epoch 24/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0193 - iou: 0.9807 - dice_coe: 0.8584 - precision: 0.8915 - recall: 0.8920 - accuracy: 0.9841 - val_loss: 0.0137 - val_iou: 0.9863 - val_dice_coe: 0.8937 - val_precision: 0.9229 - val_recall: 0.9062 - val_accuracy: 0.9888
# Epoch 25/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0197 - iou: 0.9803 - dice_coe: 0.8506 - precision: 0.8940 - recall: 0.8838 - accuracy: 0.9841 - val_loss: 0.0135 - val_iou: 0.9865 - val_dice_coe: 0.8944 - val_precision: 0.9164 - val_recall: 0.9125 - val_accuracy: 0.9889
# Epoch 26/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0181 - iou: 0.9819 - dice_coe: 0.8676 - precision: 0.9012 - recall: 0.9008 - accuracy: 0.9853 - val_loss: 0.0135 - val_iou: 0.9865 - val_dice_coe: 0.8960 - val_precision: 0.9129 - val_recall: 0.9150 - val_accuracy: 0.9890
# Epoch 27/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0174 - iou: 0.9826 - dice_coe: 0.8695 - precision: 0.8974 - recall: 0.9072 - accuracy: 0.9857 - val_loss: 0.0134 - val_iou: 0.9866 - val_dice_coe: 0.8967 - val_precision: 0.9259 - val_recall: 0.9053 - val_accuracy: 0.9891
# Epoch 28/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0174 - iou: 0.9826 - dice_coe: 0.8742 - precision: 0.9116 - recall: 0.9004 - accuracy: 0.9860 - val_loss: 0.0130 - val_iou: 0.9870 - val_dice_coe: 0.8986 - val_precision: 0.9294 - val_recall: 0.9077 - val_accuracy: 0.9894
# Epoch 29/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0180 - iou: 0.9820 - dice_coe: 0.8641 - precision: 0.9009 - recall: 0.8968 - accuracy: 0.9855 - val_loss: 0.0130 - val_iou: 0.9870 - val_dice_coe: 0.8989 - val_precision: 0.9200 - val_recall: 0.9153 - val_accuracy: 0.9893
# Epoch 30/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0172 - iou: 0.9828 - dice_coe: 0.8724 - precision: 0.9060 - recall: 0.9050 - accuracy: 0.9861 - val_loss: 0.0127 - val_iou: 0.9873 - val_dice_coe: 0.9007 - val_precision: 0.9284 - val_recall: 0.9116 - val_accuracy: 0.9896
# Epoch 31/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0175 - iou: 0.9825 - dice_coe: 0.8685 - precision: 0.8980 - recall: 0.9018 - accuracy: 0.9857 - val_loss: 0.0126 - val_iou: 0.9874 - val_dice_coe: 0.9017 - val_precision: 0.9275 - val_recall: 0.9134 - val_accuracy: 0.9897
# Epoch 32/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0175 - iou: 0.9825 - dice_coe: 0.8683 - precision: 0.8992 - recall: 0.9015 - accuracy: 0.9856 - val_loss: 0.0129 - val_iou: 0.9871 - val_dice_coe: 0.8992 - val_precision: 0.9198 - val_recall: 0.9162 - val_accuracy: 0.9895
# Epoch 33/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0161 - iou: 0.9839 - dice_coe: 0.8778 - precision: 0.9084 - recall: 0.9106 - accuracy: 0.9870 - val_loss: 0.0126 - val_iou: 0.9874 - val_dice_coe: 0.9006 - val_precision: 0.9314 - val_recall: 0.9095 - val_accuracy: 0.9897
# Epoch 34/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0159 - iou: 0.9841 - dice_coe: 0.8797 - precision: 0.9136 - recall: 0.9072 - accuracy: 0.9871 - val_loss: 0.0125 - val_iou: 0.9875 - val_dice_coe: 0.9024 - val_precision: 0.9292 - val_recall: 0.9133 - val_accuracy: 0.9897
# Epoch 35/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0159 - iou: 0.9841 - dice_coe: 0.8821 - precision: 0.9118 - recall: 0.9115 - accuracy: 0.9870 - val_loss: 0.0122 - val_iou: 0.9878 - val_dice_coe: 0.9029 - val_precision: 0.9318 - val_recall: 0.9131 - val_accuracy: 0.9900
# Epoch 36/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0157 - iou: 0.9843 - dice_coe: 0.8795 - precision: 0.9118 - recall: 0.9110 - accuracy: 0.9872 - val_loss: 0.0120 - val_iou: 0.9880 - val_dice_coe: 0.9048 - val_precision: 0.9299 - val_recall: 0.9166 - val_accuracy: 0.9901
# Epoch 37/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0149 - iou: 0.9851 - dice_coe: 0.8882 - precision: 0.9124 - recall: 0.9190 - accuracy: 0.9877 - val_loss: 0.0120 - val_iou: 0.9880 - val_dice_coe: 0.9056 - val_precision: 0.9331 - val_recall: 0.9146 - val_accuracy: 0.9903
# Epoch 38/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0151 - iou: 0.9849 - dice_coe: 0.8847 - precision: 0.9122 - recall: 0.9134 - accuracy: 0.9875 - val_loss: 0.0120 - val_iou: 0.9880 - val_dice_coe: 0.9054 - val_precision: 0.9350 - val_recall: 0.9128 - val_accuracy: 0.9903
# Epoch 39/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0151 - iou: 0.9849 - dice_coe: 0.8873 - precision: 0.9148 - recall: 0.9144 - accuracy: 0.9876 - val_loss: 0.0118 - val_iou: 0.9882 - val_dice_coe: 0.9064 - val_precision: 0.9315 - val_recall: 0.9170 - val_accuracy: 0.9903
# Epoch 40/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0149 - iou: 0.9851 - dice_coe: 0.8874 - precision: 0.9110 - recall: 0.9174 - accuracy: 0.9879 - val_loss: 0.0118 - val_iou: 0.9882 - val_dice_coe: 0.9074 - val_precision: 0.9377 - val_recall: 0.9128 - val_accuracy: 0.9905
# Epoch 41/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0142 - iou: 0.9858 - dice_coe: 0.8926 - precision: 0.9201 - recall: 0.9162 - accuracy: 0.9884 - val_loss: 0.0117 - val_iou: 0.9883 - val_dice_coe: 0.9084 - val_precision: 0.9361 - val_recall: 0.9157 - val_accuracy: 0.9905
# Epoch 42/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0146 - iou: 0.9854 - dice_coe: 0.8885 - precision: 0.9143 - recall: 0.9166 - accuracy: 0.9881 - val_loss: 0.0116 - val_iou: 0.9884 - val_dice_coe: 0.9090 - val_precision: 0.9302 - val_recall: 0.9212 - val_accuracy: 0.9905
# Epoch 43/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0140 - iou: 0.9860 - dice_coe: 0.8942 - precision: 0.9200 - recall: 0.9197 - accuracy: 0.9884 - val_loss: 0.0117 - val_iou: 0.9883 - val_dice_coe: 0.9080 - val_precision: 0.9345 - val_recall: 0.9167 - val_accuracy: 0.9905
# Epoch 44/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0140 - iou: 0.9860 - dice_coe: 0.8927 - precision: 0.9166 - recall: 0.9196 - accuracy: 0.9886 - val_loss: 0.0116 - val_iou: 0.9884 - val_dice_coe: 0.9093 - val_precision: 0.9303 - val_recall: 0.9212 - val_accuracy: 0.9904
# Epoch 45/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0145 - iou: 0.9855 - dice_coe: 0.8898 - precision: 0.9147 - recall: 0.9205 - accuracy: 0.9881 - val_loss: 0.0117 - val_iou: 0.9883 - val_dice_coe: 0.9080 - val_precision: 0.9367 - val_recall: 0.9165 - val_accuracy: 0.9905
# Epoch 46/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0144 - iou: 0.9856 - dice_coe: 0.8899 - precision: 0.9147 - recall: 0.9208 - accuracy: 0.9881 - val_loss: 0.0115 - val_iou: 0.9885 - val_dice_coe: 0.9094 - val_precision: 0.9346 - val_recall: 0.9201 - val_accuracy: 0.9907
# Epoch 47/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0142 - iou: 0.9858 - dice_coe: 0.8901 - precision: 0.9121 - recall: 0.9229 - accuracy: 0.9883 - val_loss: 0.0113 - val_iou: 0.9887 - val_dice_coe: 0.9116 - val_precision: 0.9342 - val_recall: 0.9216 - val_accuracy: 0.9908
# Epoch 48/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0132 - iou: 0.9868 - dice_coe: 0.9005 - precision: 0.9227 - recall: 0.9246 - accuracy: 0.9892 - val_loss: 0.0113 - val_iou: 0.9887 - val_dice_coe: 0.9113 - val_precision: 0.9382 - val_recall: 0.9178 - val_accuracy: 0.9908
# Epoch 49/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0131 - iou: 0.9869 - dice_coe: 0.8976 - precision: 0.9209 - recall: 0.9255 - accuracy: 0.9894 - val_loss: 0.0111 - val_iou: 0.9889 - val_dice_coe: 0.9125 - val_precision: 0.9378 - val_recall: 0.9199 - val_accuracy: 0.9909
# Epoch 50/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0134 - iou: 0.9866 - dice_coe: 0.8992 - precision: 0.9200 - recall: 0.9247 - accuracy: 0.9890 - val_loss: 0.0109 - val_iou: 0.9891 - val_dice_coe: 0.9132 - val_precision: 0.9326 - val_recall: 0.9264 - val_accuracy: 0.9910
# Epoch 51/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0131 - iou: 0.9869 - dice_coe: 0.8967 - precision: 0.9176 - recall: 0.9265 - accuracy: 0.9892 - val_loss: 0.0109 - val_iou: 0.9891 - val_dice_coe: 0.9131 - val_precision: 0.9388 - val_recall: 0.9205 - val_accuracy: 0.9910
# Epoch 52/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0130 - iou: 0.9870 - dice_coe: 0.8979 - precision: 0.9243 - recall: 0.9232 - accuracy: 0.9894 - val_loss: 0.0109 - val_iou: 0.9891 - val_dice_coe: 0.9133 - val_precision: 0.9323 - val_recall: 0.9269 - val_accuracy: 0.9910
# Epoch 53/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0130 - iou: 0.9870 - dice_coe: 0.8982 - precision: 0.9210 - recall: 0.9251 - accuracy: 0.9892 - val_loss: 0.0106 - val_iou: 0.9894 - val_dice_coe: 0.9148 - val_precision: 0.9444 - val_recall: 0.9198 - val_accuracy: 0.9914
# Epoch 54/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0127 - iou: 0.9873 - dice_coe: 0.9055 - precision: 0.9265 - recall: 0.9267 - accuracy: 0.9895 - val_loss: 0.0105 - val_iou: 0.9895 - val_dice_coe: 0.9164 - val_precision: 0.9431 - val_recall: 0.9226 - val_accuracy: 0.9913
# Epoch 55/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0129 - iou: 0.9871 - dice_coe: 0.8991 - precision: 0.9232 - recall: 0.9259 - accuracy: 0.9895 - val_loss: 0.0105 - val_iou: 0.9895 - val_dice_coe: 0.9152 - val_precision: 0.9441 - val_recall: 0.9210 - val_accuracy: 0.9914
# Epoch 56/100
# 787/787 [==============================] - 23s 30ms/step - loss: 0.0125 - iou: 0.9875 - dice_coe: 0.9055 - precision: 0.9263 - recall: 0.9291 - accuracy: 0.9898 - val_loss: 0.0105 - val_iou: 0.9895 - val_dice_coe: 0.9170 - val_precision: 0.9448 - val_recall: 0.9225 - val_accuracy: 0.9915
# Epoch 57/100
# 787/787 [==============================] - 23s 30ms/step - loss: 0.0124 - iou: 0.9876 - dice_coe: 0.9050 - precision: 0.9293 - recall: 0.9272 - accuracy: 0.9898 - val_loss: 0.0104 - val_iou: 0.9896 - val_dice_coe: 0.9158 - val_precision: 0.9384 - val_recall: 0.9253 - val_accuracy: 0.9914
# Epoch 58/100
# 787/787 [==============================] - 23s 30ms/step - loss: 0.0125 - iou: 0.9875 - dice_coe: 0.9039 - precision: 0.9254 - recall: 0.9297 - accuracy: 0.9898 - val_loss: 0.0103 - val_iou: 0.9897 - val_dice_coe: 0.9164 - val_precision: 0.9349 - val_recall: 0.9298 - val_accuracy: 0.9914
# Epoch 59/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0124 - iou: 0.9876 - dice_coe: 0.9047 - precision: 0.9281 - recall: 0.9283 - accuracy: 0.9898 - val_loss: 0.0103 - val_iou: 0.9897 - val_dice_coe: 0.9166 - val_precision: 0.9458 - val_recall: 0.9213 - val_accuracy: 0.9916
# Epoch 60/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0122 - iou: 0.9878 - dice_coe: 0.9061 - precision: 0.9310 - recall: 0.9276 - accuracy: 0.9900 - val_loss: 0.0101 - val_iou: 0.9899 - val_dice_coe: 0.9184 - val_precision: 0.9423 - val_recall: 0.9273 - val_accuracy: 0.9917
# Epoch 61/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0125 - iou: 0.9875 - dice_coe: 0.9005 - precision: 0.9231 - recall: 0.9311 - accuracy: 0.9896 - val_loss: 0.0101 - val_iou: 0.9899 - val_dice_coe: 0.9181 - val_precision: 0.9453 - val_recall: 0.9231 - val_accuracy: 0.9917
# Epoch 62/100
# 787/787 [==============================] - 23s 30ms/step - loss: 0.0120 - iou: 0.9880 - dice_coe: 0.9032 - precision: 0.9280 - recall: 0.9285 - accuracy: 0.9902 - val_loss: 0.0101 - val_iou: 0.9899 - val_dice_coe: 0.9180 - val_precision: 0.9382 - val_recall: 0.9301 - val_accuracy: 0.9917
# Epoch 63/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0122 - iou: 0.9878 - dice_coe: 0.9056 - precision: 0.9241 - recall: 0.9329 - accuracy: 0.9899 - val_loss: 0.0101 - val_iou: 0.9899 - val_dice_coe: 0.9190 - val_precision: 0.9432 - val_recall: 0.9261 - val_accuracy: 0.9917
# Epoch 64/100
# 787/787 [==============================] - 23s 30ms/step - loss: 0.0118 - iou: 0.9882 - dice_coe: 0.9076 - precision: 0.9315 - recall: 0.9329 - accuracy: 0.9903 - val_loss: 0.0100 - val_iou: 0.9900 - val_dice_coe: 0.9192 - val_precision: 0.9440 - val_recall: 0.9265 - val_accuracy: 0.9917
# Epoch 65/100
# 787/787 [==============================] - 23s 30ms/step - loss: 0.0119 - iou: 0.9881 - dice_coe: 0.9070 - precision: 0.9307 - recall: 0.9292 - accuracy: 0.9902 - val_loss: 0.0099 - val_iou: 0.9901 - val_dice_coe: 0.9205 - val_precision: 0.9421 - val_recall: 0.9299 - val_accuracy: 0.9918
# Epoch 66/100
# 787/787 [==============================] - 23s 30ms/step - loss: 0.0116 - iou: 0.9884 - dice_coe: 0.9135 - precision: 0.9353 - recall: 0.9328 - accuracy: 0.9905 - val_loss: 0.0098 - val_iou: 0.9902 - val_dice_coe: 0.9206 - val_precision: 0.9428 - val_recall: 0.9306 - val_accuracy: 0.9919
# Epoch 67/100
# 787/787 [==============================] - 23s 30ms/step - loss: 0.0117 - iou: 0.9883 - dice_coe: 0.9068 - precision: 0.9291 - recall: 0.9321 - accuracy: 0.9904 - val_loss: 0.0098 - val_iou: 0.9902 - val_dice_coe: 0.9207 - val_precision: 0.9477 - val_recall: 0.9262 - val_accuracy: 0.9920
# Epoch 68/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0115 - iou: 0.9885 - dice_coe: 0.9101 - precision: 0.9337 - recall: 0.9325 - accuracy: 0.9906 - val_loss: 0.0098 - val_iou: 0.9902 - val_dice_coe: 0.9203 - val_precision: 0.9457 - val_recall: 0.9273 - val_accuracy: 0.9919
# Epoch 69/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0115 - iou: 0.9885 - dice_coe: 0.9097 - precision: 0.9324 - recall: 0.9314 - accuracy: 0.9906 - val_loss: 0.0096 - val_iou: 0.9904 - val_dice_coe: 0.9217 - val_precision: 0.9469 - val_recall: 0.9290 - val_accuracy: 0.9921
# Epoch 70/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0115 - iou: 0.9885 - dice_coe: 0.9091 - precision: 0.9314 - recall: 0.9357 - accuracy: 0.9905 - val_loss: 0.0097 - val_iou: 0.9903 - val_dice_coe: 0.9216 - val_precision: 0.9377 - val_recall: 0.9357 - val_accuracy: 0.9919
# Epoch 71/100
# 787/787 [==============================] - 23s 30ms/step - loss: 0.0113 - iou: 0.9887 - dice_coe: 0.9121 - precision: 0.9332 - recall: 0.9335 - accuracy: 0.9906 - val_loss: 0.0096 - val_iou: 0.9904 - val_dice_coe: 0.9218 - val_precision: 0.9445 - val_recall: 0.9310 - val_accuracy: 0.9921
# Epoch 72/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0114 - iou: 0.9886 - dice_coe: 0.9124 - precision: 0.9339 - recall: 0.9337 - accuracy: 0.9907 - val_loss: 0.0097 - val_iou: 0.9903 - val_dice_coe: 0.9224 - val_precision: 0.9456 - val_recall: 0.9294 - val_accuracy: 0.9920
# Epoch 73/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0112 - iou: 0.9888 - dice_coe: 0.9118 - precision: 0.9323 - recall: 0.9349 - accuracy: 0.9908 - val_loss: 0.0095 - val_iou: 0.9905 - val_dice_coe: 0.9233 - val_precision: 0.9527 - val_recall: 0.9254 - val_accuracy: 0.9922
# Epoch 74/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0117 - iou: 0.9883 - dice_coe: 0.9082 - precision: 0.9331 - recall: 0.9316 - accuracy: 0.9904 - val_loss: 0.0095 - val_iou: 0.9905 - val_dice_coe: 0.9237 - val_precision: 0.9387 - val_recall: 0.9380 - val_accuracy: 0.9920
# Epoch 75/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0113 - iou: 0.9887 - dice_coe: 0.9133 - precision: 0.9347 - recall: 0.9350 - accuracy: 0.9907 - val_loss: 0.0095 - val_iou: 0.9905 - val_dice_coe: 0.9228 - val_precision: 0.9449 - val_recall: 0.9318 - val_accuracy: 0.9921
# Epoch 76/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0110 - iou: 0.9890 - dice_coe: 0.9149 - precision: 0.9382 - recall: 0.9354 - accuracy: 0.9909 - val_loss: 0.0093 - val_iou: 0.9907 - val_dice_coe: 0.9234 - val_precision: 0.9455 - val_recall: 0.9329 - val_accuracy: 0.9923
# Epoch 77/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0111 - iou: 0.9889 - dice_coe: 0.9113 - precision: 0.9344 - recall: 0.9334 - accuracy: 0.9908 - val_loss: 0.0094 - val_iou: 0.9906 - val_dice_coe: 0.9238 - val_precision: 0.9435 - val_recall: 0.9353 - val_accuracy: 0.9922
# Epoch 78/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0108 - iou: 0.9892 - dice_coe: 0.9130 - precision: 0.9344 - recall: 0.9372 - accuracy: 0.9911 - val_loss: 0.0092 - val_iou: 0.9908 - val_dice_coe: 0.9253 - val_precision: 0.9500 - val_recall: 0.9306 - val_accuracy: 0.9924
# Epoch 79/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0109 - iou: 0.9891 - dice_coe: 0.9135 - precision: 0.9346 - recall: 0.9374 - accuracy: 0.9910 - val_loss: 0.0093 - val_iou: 0.9907 - val_dice_coe: 0.9244 - val_precision: 0.9472 - val_recall: 0.9320 - val_accuracy: 0.9923
# Epoch 80/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0109 - iou: 0.9891 - dice_coe: 0.9168 - precision: 0.9386 - recall: 0.9354 - accuracy: 0.9910 - val_loss: 0.0092 - val_iou: 0.9908 - val_dice_coe: 0.9257 - val_precision: 0.9503 - val_recall: 0.9309 - val_accuracy: 0.9924
# Epoch 81/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0109 - iou: 0.9891 - dice_coe: 0.9149 - precision: 0.9363 - recall: 0.9369 - accuracy: 0.9910 - val_loss: 0.0093 - val_iou: 0.9907 - val_dice_coe: 0.9246 - val_precision: 0.9481 - val_recall: 0.9311 - val_accuracy: 0.9923
# Epoch 82/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0105 - iou: 0.9895 - dice_coe: 0.9182 - precision: 0.9374 - recall: 0.9391 - accuracy: 0.9913 - val_loss: 0.0092 - val_iou: 0.9908 - val_dice_coe: 0.9258 - val_precision: 0.9462 - val_recall: 0.9346 - val_accuracy: 0.9923
# Epoch 83/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0107 - iou: 0.9893 - dice_coe: 0.9159 - precision: 0.9364 - recall: 0.9377 - accuracy: 0.9911 - val_loss: 0.0092 - val_iou: 0.9908 - val_dice_coe: 0.9263 - val_precision: 0.9490 - val_recall: 0.9331 - val_accuracy: 0.9925
# Epoch 84/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0106 - iou: 0.9894 - dice_coe: 0.9173 - precision: 0.9386 - recall: 0.9382 - accuracy: 0.9913 - val_loss: 0.0091 - val_iou: 0.9909 - val_dice_coe: 0.9262 - val_precision: 0.9496 - val_recall: 0.9327 - val_accuracy: 0.9925
# Epoch 85/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0108 - iou: 0.9892 - dice_coe: 0.9110 - precision: 0.9371 - recall: 0.9356 - accuracy: 0.9912 - val_loss: 0.0091 - val_iou: 0.9909 - val_dice_coe: 0.9259 - val_precision: 0.9472 - val_recall: 0.9349 - val_accuracy: 0.9924
# Epoch 86/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0106 - iou: 0.9894 - dice_coe: 0.9184 - precision: 0.9390 - recall: 0.9374 - accuracy: 0.9912 - val_loss: 0.0091 - val_iou: 0.9909 - val_dice_coe: 0.9251 - val_precision: 0.9481 - val_recall: 0.9336 - val_accuracy: 0.9924
# Epoch 87/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0105 - iou: 0.9895 - dice_coe: 0.9168 - precision: 0.9359 - recall: 0.9403 - accuracy: 0.9914 - val_loss: 0.0091 - val_iou: 0.9909 - val_dice_coe: 0.9268 - val_precision: 0.9442 - val_recall: 0.9387 - val_accuracy: 0.9925
# Epoch 88/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0105 - iou: 0.9895 - dice_coe: 0.9155 - precision: 0.9361 - recall: 0.9390 - accuracy: 0.9913 - val_loss: 0.0091 - val_iou: 0.9909 - val_dice_coe: 0.9265 - val_precision: 0.9499 - val_recall: 0.9327 - val_accuracy: 0.9925
# Epoch 89/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0105 - iou: 0.9895 - dice_coe: 0.9179 - precision: 0.9375 - recall: 0.9382 - accuracy: 0.9913 - val_loss: 0.0091 - val_iou: 0.9909 - val_dice_coe: 0.9265 - val_precision: 0.9448 - val_recall: 0.9384 - val_accuracy: 0.9925
# Epoch 90/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0102 - iou: 0.9898 - dice_coe: 0.9173 - precision: 0.9375 - recall: 0.9397 - accuracy: 0.9916 - val_loss: 0.0090 - val_iou: 0.9910 - val_dice_coe: 0.9274 - val_precision: 0.9487 - val_recall: 0.9354 - val_accuracy: 0.9925
# Epoch 91/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0102 - iou: 0.9898 - dice_coe: 0.9205 - precision: 0.9411 - recall: 0.9396 - accuracy: 0.9914 - val_loss: 0.0087 - val_iou: 0.9913 - val_dice_coe: 0.9294 - val_precision: 0.9482 - val_recall: 0.9393 - val_accuracy: 0.9928
# Epoch 92/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0105 - iou: 0.9895 - dice_coe: 0.9162 - precision: 0.9352 - recall: 0.9382 - accuracy: 0.9913 - val_loss: 0.0087 - val_iou: 0.9913 - val_dice_coe: 0.9295 - val_precision: 0.9458 - val_recall: 0.9414 - val_accuracy: 0.9927
# Epoch 93/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0103 - iou: 0.9897 - dice_coe: 0.9181 - precision: 0.9381 - recall: 0.9382 - accuracy: 0.9915 - val_loss: 0.0088 - val_iou: 0.9912 - val_dice_coe: 0.9290 - val_precision: 0.9537 - val_recall: 0.9342 - val_accuracy: 0.9928
# Epoch 94/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0102 - iou: 0.9898 - dice_coe: 0.9173 - precision: 0.9381 - recall: 0.9390 - accuracy: 0.9915 - val_loss: 0.0087 - val_iou: 0.9913 - val_dice_coe: 0.9300 - val_precision: 0.9504 - val_recall: 0.9383 - val_accuracy: 0.9928
# Epoch 95/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0103 - iou: 0.9897 - dice_coe: 0.9191 - precision: 0.9370 - recall: 0.9394 - accuracy: 0.9915 - val_loss: 0.0088 - val_iou: 0.9912 - val_dice_coe: 0.9291 - val_precision: 0.9476 - val_recall: 0.9398 - val_accuracy: 0.9928
# Epoch 96/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0103 - iou: 0.9897 - dice_coe: 0.9218 - precision: 0.9411 - recall: 0.9410 - accuracy: 0.9915 - val_loss: 0.0086 - val_iou: 0.9914 - val_dice_coe: 0.9294 - val_precision: 0.9521 - val_recall: 0.9376 - val_accuracy: 0.9929
# Epoch 97/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0101 - iou: 0.9899 - dice_coe: 0.9220 - precision: 0.9394 - recall: 0.9424 - accuracy: 0.9917 - val_loss: 0.0085 - val_iou: 0.9915 - val_dice_coe: 0.9300 - val_precision: 0.9528 - val_recall: 0.9374 - val_accuracy: 0.9929
# Epoch 98/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0101 - iou: 0.9899 - dice_coe: 0.9213 - precision: 0.9410 - recall: 0.9402 - accuracy: 0.9916 - val_loss: 0.0088 - val_iou: 0.9912 - val_dice_coe: 0.9289 - val_precision: 0.9447 - val_recall: 0.9422 - val_accuracy: 0.9927
# Epoch 99/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0102 - iou: 0.9898 - dice_coe: 0.9185 - precision: 0.9370 - recall: 0.9414 - accuracy: 0.9915 - val_loss: 0.0087 - val_iou: 0.9913 - val_dice_coe: 0.9289 - val_precision: 0.9480 - val_recall: 0.9401 - val_accuracy: 0.9928
# Epoch 100/100
# 787/787 [==============================] - 23s 29ms/step - loss: 0.0098 - iou: 0.9902 - dice_coe: 0.9199 - precision: 0.9369 - recall: 0.9455 - accuracy: 0.9918 - val_loss: 0.0087 - val_iou: 0.9913 - val_dice_coe: 0.9299 - val_precision: 0.9495 - val_recall: 0.9394 - val_accuracy: 0.9928

# %%
model.load_weights('/content/drive/My Drive/models/20200712_total_100_epoch.h5')

print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 787/787 [==============================] - 6s 7ms/step
# ________________________
# IOU:       |   99.20  |
# Dice Coef: |   94.22  |
# Precision: |   95.47  |
# Recall:    |   95.44  |
# Accuracy:  |   99.32  |
# Loss:      |   0.80  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 20/20 [==============================] - 0s 6ms/step
# ________________________
# IOU:       |   98.86  |
# Dice Coef: |   93.99  |
# Precision: |   95.91  |
# Recall:    |   94.81  |
# Accuracy:  |   99.28  |
# Loss:      |   1.14  |
# ________________________
#
# -------------On validation Set---------------------
#
# 197/197 [==============================] - 2s 9ms/step
# ________________________
# IOU:       |   99.13  |
# Dice Coef: |   93.77  |
# Precision: |   95.49  |
# Recall:    |   94.55  |
# Accuracy:  |   99.28  |
# Loss:      |   0.87  |
# ________________________

# %%
for i in range(len(x_train)):
  plt.figure(figsize=(12,4))
  plt.subplot(1,3,1)
  plt.title('Origin Image')
  plt.imshow(x_train[i])
  plt.subplot(1,3,2)
  plt.title('Ground Truth')
  plt.imshow(y_train[i], plt.cm.binary_r)
  plt.subplot(1,3,3)
  plt.title('Predicted')
  plt.imshow(enhance(x_train[i], '20200712_total_100_epoch.h5').reshape(224,224), plt.cm.binary_r)
  # plt.subplot(3,2,5)
  # plt.title('Ground_Truth_out')
  # plt.imshow(Y_train_out[i],plt.cm.binary_r)
  # plt.subplot(3,2,6)
  # plt.title('Predicted_out')
  # plt.imshow(enhance_out(X_train[i]).reshape(224,224),plt.cm.binary_r)
  plt.savefig('/content/drive/My Drive/results/total/20200712_total_train/' + str(i) + '.jpg')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sum_iou = 0
sum_dice = 0
sum_acc = 0

for i in range(len(x_test)):
  pdata = (model.predict(x_test[i].reshape(1,224,224,3))).reshape(1,224,224,1)
  # print(pdata.shape)
  # ensemble = np.zeros((1,224,224,1))
  # print(pdata.shape)
  # for j in range(224) :
  #       for k in range(224) :
  #           ensemble[i][j][[k]0] = pdata[j][k][0]
  ensemble = pdata
  ensemble = ensemble * 255
  ensemble = ensemble.squeeze(axis=0)
  # print(ensemble.shape)
  ensemble = ensemble.astype(np.uint8)
  ret3, th3 = cv2.threshold(ensemble, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)


  th3 = th3/255
  # print(th3.shape)
  # print(y_test[i].shape)
  A = 1
  cnt = 1
  B = 1
  C = 0
  top = 0
  bottom = 0

  for j in range(224) :
      for k in range(224) : 
          A += y_test[i][j][k]
          B += th3[j][k]     
          if y_test[i][j][k] == th3[j][k] : # 00, 11 인 경우
              cnt += th3[j][k]
              top += th3[j][k]
              bottom += th3[j][k]
              C+=1
          else : # 01 10 인 경우
              bottom += 1
  
  dice = cnt*2 / (A+B) 
  iou = top / bottom
  acc = C / (224*224)
  
  sum_acc += acc
  sum_iou +=iou
  sum_dice += dice
  print(i , '번째 사진의 정확도 ')
  print('iou : ' , iou)
  print('dice : ' , dice)
  print('acc : ', acc)
  print()
  inputStr = 'Image ' + str(i) + '\n' + 'iou : ' + str(iou) + '\ndice : ' + str(dice) + '\nacc : ' + str(acc) + '\n'
  # print(inputStr)


  plt.figure(figsize=(12,6))
  ax1 = plt.subplot(2,4,5)
  plt.title('Origin Image')
  plt.imshow(x_test[i])
  plt.subplot(2,4,6)
  plt.title('Ground Truth')
  plt.imshow(y_test[i], plt.cm.binary_r)
  plt.subplot(2,4,7)
  plt.title('Predicted')
  plt.imshow(enhance(x_test[i], '20200712_total_100_epoch.h5').reshape(224,224), plt.cm.binary_r)
  plt.subplot(2,4,8)
  plt.imshow(th3.squeeze(), plt.cm.binary_r)
  plt.title('binarization')
  plt.axis('off')
  ax1.text(0, 1.1, s = inputStr, size=12,transform=ax1.transAxes)
  plt.savefig('/content/drive/My Drive/results/total/20200712_total_test/' + str(i) + '.jpg')

print('acc : ',sum_acc/20)
print('iou : ',sum_iou/20)
print('dice : ',sum_dice/20)
# Out:
# 0 번째 사진의 정확도
# iou :  0.90860768175583
# dice :  0.9521243150992544
# acc :  0.9893773915816326
#
# 1 번째 사진의 정확도
# iou :  0.9525416104363473
# dice :  0.9756996429805367
# acc :  0.9957948022959183
#
# 2 번째 사진의 정확도
# iou :  0.9188561215370867
# dice :  0.957720245855839
# acc :  0.9909518494897959
#
# 3 번째 사진의 정확도
# iou :  0.9237879316358563
# dice :  0.9603915526148826
# acc :  0.9912906568877551
#
# 4 번째 사진의 정확도
# iou :  0.896455872133426
# dice :  0.9454092474536528
# acc :  0.9851522640306123
#
# 5 번째 사진의 정확도
# iou :  0.9418822647169104
# dice :  0.9700752944204903
# acc :  0.9907326211734694
#
# 6 번째 사진의 정확도
# iou :  0.925898752751284
# dice :  0.9615384615384616
# acc :  0.9959741709183674
#
# 7 번째 사진의 정확도
# iou :  0.9289183222958057
# dice :  0.9631578947368421
# acc :  0.9935825892857143
#
# 8 번째 사진의 정확도
# iou :  0.9385937979735953
# dice :  0.9683343888537049
# acc :  0.9960140306122449
#
# 9 번째 사진의 정확도
# iou :  0.9581673306772909
# dice :  0.9786422578184591
# acc :  0.9966517857142857
#
# 10 번째 사진의 정확도
# iou :  0.916869671132765
# dice :  0.9566460219151978
# acc :  0.9945591517857143
#
# 11 번째 사진의 정확도
# iou :  0.8519622454048683
# dice :  0.9201072386058982
# acc :  0.9940609056122449
#
# 12 번째 사진의 정확도
# iou :  0.9654929577464789
# dice :  0.9824477611940299
# acc :  0.9970703125
#
# 13 번째 사진의 정확도
# iou :  0.9508791515489813
# dice :  0.9748283752860412
# acc :  0.9964923469387755
#
# 14 번째 사진의 정확도
# iou :  0.48417061611374407
# dice :  0.6525347975992849
# acc :  0.9457708864795918
#
# 15 번째 사진의 정확도
# iou :  0.7627206645898235
# dice :  0.865469531939947
# acc :  0.9908920599489796
#
# 16 번째 사진의 정확도
# iou :  0.9631018449077546
# dice :  0.9812070282658518
# acc :  0.9950972576530612
#
# 17 번째 사진의 정확도
# iou :  0.9466868714698994
# dice :  0.9726172787094035
# acc :  0.9922871492346939
#
# 18 번째 사진의 정확도
# iou :  0.8795180722891566
# dice :  0.9359179750080102
# acc :  0.9920280612244898
#
# 19 번째 사진의 정확도
# iou :  0.9653315382026254
# dice :  0.9823660332134908
# acc :  0.9979472257653061
#
# acc :  0.9910863759566327
# iou :  0.8990221659659765
# dice :  0.9428617671554639
