# %%
# %tensorflow_version 1.x
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
np.random.seed(101)

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('/content/drive/My Drive/input/dgu_trainx/*.jpg'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

# for i in range(len(filelist_trainx)):
# X_train = np.array([np.array(Image.open(fname)) for fname])

filelist_trainy = sorted(glob.glob('/content/drive/My Drive/input/dgu_trainy_out/*.jpg'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

print(len(filelist_trainx))
print(len(filelist_trainy))
# print(len(filelist_trainy_out))
# Out:
# 102
# 102

# %%
print(X_train[0].shape)
print(Y_train[0].shape)
# print(Y_train_out[0].shape)
# Out:
# (700, 1440, 3)
# (700, 1440, 3)

# %%
def resizeX(filename, size = (224,224)):
    im = Image.open(filename)
    im_resized = im.resize(size)
    return (im_resized)

def resizeY(filename, size = (224,224)):
    im = Image.open(filename)
    im_resized = im.resize(size).convert('1')
    return (im_resized)

# %%
X_train_ph2_resized = []
Y_train_ph2_resized = []

for i in range(len(filelist_trainx)):
    X_train_ph2_resized.append(resizeX(filelist_trainx[i]))
    Y_train_ph2_resized.append(resizeY(filelist_trainy[i]))

# %%
del(X_train)
del(Y_train)

X_train = np.array([np.array(img) for img in X_train_ph2_resized])
Y_train = np.array([np.array(img) for img in Y_train_ph2_resized])
# for k in range(len(filelist_trainy)):
#   for i in range(224):
#     for j in range(224):
#       if Y_train[k][i][j] <= 30:
#         Y_train[k][i][j] = 0
#       elif Y_train[k][i][j] <= 160:
#         Y_train[k][i][j] = 1
#       else:
#         Y_train[k][i][j] = 2

# %%
print(X_train[0].shape)
print(Y_train[0].shape)

plt.figure(figsize=(20,9))
plt.subplot(3,4,1)
plt.imshow(X_train[0])
plt.subplot(3,4,5)
plt.imshow(Y_train[0])
# Out:
# (224, 224, 3)
# (224, 224)

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(x_train[1])
plt.subplot(2,4,2)
plt.imshow(y_train[1])
plt.show()

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
def dice_coe(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)

# %%
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print(x_train[0].shape)
print(y_train[0].shape)
# Out:
# (224, 224, 3)
# (224, 224)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 364
# Length of the Test Set       : 26
# Length of the Validation Set : 92

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
INPUT_CHANNELS = 3
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
# Pretrained weights

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.common.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_224(epochs_num, savename, x_train, y_train, x_val, y_val):
    dropout_val=0.50
    if K.common.image_dim_ordering() == 'th':
        inputs = Input((INPUT_CHANNELS, 224, 224))
        axis = 1
    else:
        inputs = Input((224, 224, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224,224))(conv_final)
    model = Model(inputs, pred, name="UNET_224")
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 3,validation_data=(x_val, y_val), verbose=1)
    model.save(savename)
    return model, hist

# %%
model, hist = UNET_224(1, 'dgu_unet_1_epoch.h5', x_train, y_train, x_val, y_val)
# model_out, hist_out = UNET_224(1, 'dgu_unet_1_epoch_out.h5', x_train_out, y_train_out, x_val_out, y_val_out)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "UNET_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 32) 9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 224, 224, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 112, 112, 32) 0           spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 64) 36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 112, 112, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 112, 112, 64) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 64)   0           spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 56, 56, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 128)  0           spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_4 (SpatialDro (None, 28, 28, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 256)  0           spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 512)  2359808     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_5 (SpatialDro (None, 14, 14, 512)  0           activation_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 512)    0           spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 1024)   4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 1024)   4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_6 (SpatialDro (None, 7, 7, 1024)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 14, 14, 1024) 0           spatial_dropout2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 1536) 0           up_sampling2d_1[0][0]
#                                                                  spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 14, 14, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 512)  2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 14, 14, 512)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_7 (SpatialDro (None, 14, 14, 512)  0           activation_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 28, 28, 512)  0           spatial_dropout2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 768)  0           up_sampling2d_2[0][0]
#                                                                  spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 256)  590080      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_8 (SpatialDro (None, 28, 28, 256)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 56, 56, 256)  0           spatial_dropout2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 384)  0           up_sampling2d_3[0][0]
#                                                                  spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 56, 56, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 56, 56, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 56, 56, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 56, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_9 (SpatialDro (None, 56, 56, 128)  0           activation_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 112, 112, 128 0           spatial_dropout2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 112, 112, 192 0           up_sampling2d_4[0][0]
#                                                                  spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 112, 112, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 112, 112, 64) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 112, 112, 64) 36928       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 112, 112, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 112, 112, 64) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10 (SpatialDr (None, 112, 112, 64) 0           activation_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 224, 224, 64) 0           spatial_dropout2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 224, 224, 96) 0           up_sampling2d_5[0][0]
#                                                                  spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 224, 224, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 224, 224, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 224, 224, 32) 9248        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 224, 224, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 224, 224, 32) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_11 (SpatialDr (None, 224, 224, 32) 0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 224, 224, 1)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 224, 224)     0           activation_23[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 364 samples, validate on 92 samples
# Epoch 1/1
# 364/364 [==============================] - 31s 86ms/step - loss: 0.0906 - iou: 0.9094 - dice_coe: 0.4165 - precision: 0.6845 - recall: 0.6250 - accuracy: 0.9411 - val_loss: 0.6270 - val_iou: 0.3730 - val_dice_coe: 0.1417 - val_precision: 0.0772 - val_recall: 0.9764 - val_accuracy: 0.1038

# %%
dropout_val=0.50
if K.common.image_dim_ordering() == 'th':
    inputs = Input((INPUT_CHANNELS, 224, 224))
    axis = 1
else:
    inputs = Input((224, 224, INPUT_CHANNELS))
    axis = 3
filters = 32

conv_224 = double_conv_layer(inputs, filters)
pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

conv_112 = double_conv_layer(pool_112, 2*filters)
pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

conv_56 = double_conv_layer(pool_56, 4*filters)
pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

conv_28 = double_conv_layer(pool_28, 8*filters)
pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

conv_14 = double_conv_layer(pool_14, 16*filters)
pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

conv_7 = double_conv_layer(pool_7, 32*filters)

up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
up_conv_14 = double_conv_layer(up_14, 16*filters)

up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
up_conv_28 = double_conv_layer(up_28, 8*filters)

up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
up_conv_56 = double_conv_layer(up_56, 4*filters)

up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
up_conv_112 = double_conv_layer(up_112, 2*filters)

up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
conv_final = Activation('sigmoid')(conv_final)
pred = Reshape((224,224))(conv_final)

# %%
model_0 = Model(inputs, pred, name="UNET_224")
model_0.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])

# %%
model_0.load_weights('dgu_unet_1_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}i  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 364/364 [==============================] - 7s 20ms/step
# ________________________
# IOU:       |   37.22  |
# Dice Coef: |   13.65  |
# Precision: |   7.34  |
# Recall:    |   98.08  |
# Accuracy:  |   10.40  |
# Loss:      |   62.78  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 26/26 [==============================] - 2s 59ms/step
# ________________________
# IOU:       |   38.01  |
# Dice Coef: |   16.46  |
# Precision: |   8.97i  |
# Recall:    |   100.00  |
# Accuracy:  |   12.14  |
# Loss:      |   61.99  |
# ________________________
#
# -------------On validation Set---------------------
#
# 92/92 [==============================] - 1s 10ms/step
# ________________________
# IOU:       |   37.30  |
# Dice Coef: |   13.77  |
# Precision: |   7.43  |
# Recall:    |   96.97  |
# Accuracy:  |   9.90  |
# Loss:      |   62.70  |
# ________________________

# %%
model, hist = UNET_224(100, '/content/drive/My Drive/models/dgu_unet_100_epoch.h5', x_train, y_train, x_val, y_val)
# model_out, hist_out = UNET_224(100, 'dgu_unet_100_epoch_out.h5', x_train_out, y_train_out, x_val_out, y_val_out)
# Out:
# Model: "UNET_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 224, 224, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 224, 224, 32) 128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 224, 224, 32) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 224, 224, 32) 9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 224, 224, 32) 128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 224, 224, 32) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_23 (SpatialDr (None, 224, 224, 32) 0           activation_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 112, 112, 32) 0           spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 112, 112, 64) 18496       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 112, 112, 64) 256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 112, 112, 64) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 112, 112, 64) 36928       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 112, 112, 64) 256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 112, 112, 64) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_24 (SpatialDr (None, 112, 112, 64) 0           activation_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 56, 56, 64)   0           spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 56, 56, 128)  73856       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 56, 56, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 56, 56, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 56, 56, 128)  147584      activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 56, 56, 128)  512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 56, 56, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_25 (SpatialDr (None, 56, 56, 128)  0           activation_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 28, 28, 128)  0           spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 28, 28, 256)  295168      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 28, 28, 256)  1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 28, 28, 256)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 28, 28, 256)  590080      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 28, 28, 256)  1024        conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 28, 28, 256)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_26 (SpatialDr (None, 28, 28, 256)  0           activation_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 14, 14, 256)  0           spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 512)  1180160     max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 14, 14, 512)  2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 14, 14, 512)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 14, 14, 512)  2359808     activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 14, 14, 512)  2048        conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 14, 14, 512)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_27 (SpatialDr (None, 14, 14, 512)  0           activation_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 7, 7, 512)    0           spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 7, 7, 1024)   4096        conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 7, 7, 1024)   4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_28 (SpatialDr (None, 7, 7, 1024)   0           activation_58[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 14, 14, 1024) 0           spatial_dropout2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 14, 14, 1536) 0           up_sampling2d_11[0][0]
#                                                                  spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 14, 14, 512)  2048        conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 14, 14, 512)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 14, 14, 512)  2359808     activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 14, 14, 512)  2048        conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 14, 14, 512)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_29 (SpatialDr (None, 14, 14, 512)  0           activation_60[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 28, 28, 512)  0           spatial_dropout2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 768)  0           up_sampling2d_12[0][0]
#                                                                  spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 28, 28, 256)  1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 28, 28, 256)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 28, 28, 256)  590080      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 28, 28, 256)  1024        conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 28, 28, 256)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_30 (SpatialDr (None, 28, 28, 256)  0           activation_62[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 56, 56, 256)  0           spatial_dropout2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 56, 56, 384)  0           up_sampling2d_13[0][0]
#                                                                  spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 56, 56, 128)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 56, 56, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 56, 56, 128)  147584      activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 56, 56, 128)  512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 56, 56, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_31 (SpatialDr (None, 56, 56, 128)  0           activation_64[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 112, 112, 128 0           spatial_dropout2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 112, 112, 192 0           up_sampling2d_14[0][0]
#                                                                  spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 112, 112, 64) 256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 112, 112, 64) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 112, 112, 64) 36928       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 112, 112, 64) 256         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 112, 112, 64) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_32 (SpatialDr (None, 112, 112, 64) 0           activation_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 224, 224, 64) 0           spatial_dropout2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 224, 224, 96) 0           up_sampling2d_15[0][0]
#                                                                  spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 224, 224, 32) 128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 224, 224, 32) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 224, 224, 32) 9248        activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 224, 224, 32) 128         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 224, 224, 32) 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_33 (SpatialDr (None, 224, 224, 32) 0           activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_33[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 224, 224, 1)  0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 224, 224)     0           activation_69[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 364 samples, validate on 92 samples
# Epoch 1/100
# 364/364 [==============================] - 20s 54ms/step - loss: 0.1039 - iou: 0.8961 - dice_coe: 0.3656 - precision: 0.6378 - recall: 0.5837 - accuracy: 0.9271 - val_loss: 0.6373 - val_iou: 0.3627 - val_dice_coe: 0.1433 - val_precision: 0.0779 - val_recall: 1.0000 - val_accuracy: 0.0780
# Epoch 2/100
# 364/364 [==============================] - 17s 48ms/step - loss: 0.0550 - iou: 0.9450 - dice_coe: 0.5215 - precision: 0.7471 - recall: 0.6444 - accuracy: 0.9566 - val_loss: 0.1896 - val_iou: 0.8104 - val_dice_coe: 0.3688 - val_precision: 0.2721 - val_recall: 0.8468 - val_accuracy: 0.7930
# Epoch 3/100
# 364/364 [==============================] - 17s 48ms/step - loss: 0.0529 - iou: 0.9471 - dice_coe: 0.5494 - precision: 0.7442 - recall: 0.6679 - accuracy: 0.9574 - val_loss: 0.4789 - val_iou: 0.5211 - val_dice_coe: 0.1881 - val_precision: 0.1046 - val_recall: 0.9720 - val_accuracy: 0.3747
# Epoch 4/100
# 364/364 [==============================] - 18s 48ms/step - loss: 0.0489 - iou: 0.9511 - dice_coe: 0.5805 - precision: 0.7555 - recall: 0.6769 - accuracy: 0.9586 - val_loss: 0.0649 - val_iou: 0.9351 - val_dice_coe: 0.6367 - val_precision: 0.5856 - val_recall: 0.8354 - val_accuracy: 0.9420
# Epoch 5/100
# 364/364 [==============================] - 18s 48ms/step - loss: 0.0498 - iou: 0.9502 - dice_coe: 0.5736 - precision: 0.7573 - recall: 0.6591 - accuracy: 0.9577 - val_loss: 0.0785 - val_iou: 0.9215 - val_dice_coe: 0.5734 - val_precision: 0.5515 - val_recall: 0.8173 - val_accuracy: 0.9193
# Epoch 6/100
# 364/364 [==============================] - 18s 49ms/step - loss: 0.0449 - iou: 0.9551 - dice_coe: 0.6317 - precision: 0.7794 - recall: 0.7071 - accuracy: 0.9619 - val_loss: 0.1124 - val_iou: 0.8876 - val_dice_coe: 0.4343 - val_precision: 0.5790 - val_recall: 0.5803 - val_accuracy: 0.8854
# Epoch 7/100
# 364/364 [==============================] - 18s 49ms/step - loss: 0.0421 - iou: 0.9579 - dice_coe: 0.6337 - precision: 0.7744 - recall: 0.7286 - accuracy: 0.9630 - val_loss: 0.1416 - val_iou: 0.8584 - val_dice_coe: 0.4397 - val_precision: 0.3532 - val_recall: 0.9338 - val_accuracy: 0.8593
# Epoch 8/100
# 364/364 [==============================] - 18s 49ms/step - loss: 0.0424 - iou: 0.9576 - dice_coe: 0.6444 - precision: 0.7881 - recall: 0.7246 - accuracy: 0.9628 - val_loss: 0.0524 - val_iou: 0.9476 - val_dice_coe: 0.5926 - val_precision: 0.8832 - val_recall: 0.5322 - val_accuracy: 0.9566
# Epoch 9/100
# 364/364 [==============================] - 18s 49ms/step - loss: 0.0428 - iou: 0.9572 - dice_coe: 0.6469 - precision: 0.7878 - recall: 0.7318 - accuracy: 0.9632 - val_loss: 0.0594 - val_iou: 0.9406 - val_dice_coe: 0.6699 - val_precision: 0.5945 - val_recall: 0.8917 - val_accuracy: 0.9451
# Epoch 10/100
# 364/364 [==============================] - 18s 49ms/step - loss: 0.0402 - iou: 0.9598 - dice_coe: 0.6682 - precision: 0.8005 - recall: 0.7419 - accuracy: 0.9657 - val_loss: 0.0411 - val_iou: 0.9589 - val_dice_coe: 0.7384 - val_precision: 0.7772 - val_recall: 0.7835 - val_accuracy: 0.9654
# Epoch 11/100
# 364/364 [==============================] - 18s 49ms/step - loss: 0.0377 - iou: 0.9623 - dice_coe: 0.6830 - precision: 0.8141 - recall: 0.7591 - accuracy: 0.9670 - val_loss: 0.0625 - val_iou: 0.9375 - val_dice_coe: 0.5632 - val_precision: 0.7625 - val_recall: 0.5239 - val_accuracy: 0.9499
# Epoch 12/100
# 364/364 [==============================] - 18s 49ms/step - loss: 0.0363 - iou: 0.9637 - dice_coe: 0.7020 - precision: 0.8224 - recall: 0.7562 - accuracy: 0.9685 - val_loss: 0.0478 - val_iou: 0.9522 - val_dice_coe: 0.6649 - val_precision: 0.7079 - val_recall: 0.7484 - val_accuracy: 0.9588
# Epoch 13/100
# 364/364 [==============================] - 18s 49ms/step - loss: 0.0362 - iou: 0.9638 - dice_coe: 0.7050 - precision: 0.8170 - recall: 0.7771 - accuracy: 0.9688 - val_loss: 0.0419 - val_iou: 0.9581 - val_dice_coe: 0.6888 - val_precision: 0.8769 - val_recall: 0.6492 - val_accuracy: 0.9649
# Epoch 14/100
# 364/364 [==============================] - 18s 49ms/step - loss: 0.0333 - iou: 0.9667 - dice_coe: 0.7287 - precision: 0.8446 - recall: 0.7782 - accuracy: 0.9714 - val_loss: 0.0475 - val_iou: 0.9525 - val_dice_coe: 0.6132 - val_precision: 0.9162 - val_recall: 0.5040 - val_accuracy: 0.9580
# Epoch 15/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0323 - iou: 0.9677 - dice_coe: 0.7416 - precision: 0.8363 - recall: 0.8120 - accuracy: 0.9726 - val_loss: 0.0627 - val_iou: 0.9373 - val_dice_coe: 0.5100 - val_precision: 0.8512 - val_recall: 0.4254 - val_accuracy: 0.9510
# Epoch 16/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0300 - iou: 0.9700 - dice_coe: 0.7556 - precision: 0.8489 - recall: 0.8210 - accuracy: 0.9745 - val_loss: 0.0384 - val_iou: 0.9616 - val_dice_coe: 0.6755 - val_precision: 0.8769 - val_recall: 0.6218 - val_accuracy: 0.9649
# Epoch 17/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0305 - iou: 0.9695 - dice_coe: 0.7476 - precision: 0.8463 - recall: 0.8205 - accuracy: 0.9744 - val_loss: 0.0291 - val_iou: 0.9709 - val_dice_coe: 0.7934 - val_precision: 0.8382 - val_recall: 0.8492 - val_accuracy: 0.9759
# Epoch 18/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0272 - iou: 0.9728 - dice_coe: 0.7790 - precision: 0.8665 - recall: 0.8302 - accuracy: 0.9770 - val_loss: 0.0378 - val_iou: 0.9622 - val_dice_coe: 0.7068 - val_precision: 0.8823 - val_recall: 0.6431 - val_accuracy: 0.9670
# Epoch 19/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0255 - iou: 0.9745 - dice_coe: 0.7953 - precision: 0.8732 - recall: 0.8477 - accuracy: 0.9783 - val_loss: 0.0281 - val_iou: 0.9719 - val_dice_coe: 0.8048 - val_precision: 0.8816 - val_recall: 0.8172 - val_accuracy: 0.9768
# Epoch 20/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0230 - iou: 0.9770 - dice_coe: 0.8082 - precision: 0.8782 - recall: 0.8633 - accuracy: 0.9810 - val_loss: 0.0346 - val_iou: 0.9654 - val_dice_coe: 0.7451 - val_precision: 0.9129 - val_recall: 0.6806 - val_accuracy: 0.9709
# Epoch 21/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0269 - iou: 0.9731 - dice_coe: 0.7882 - precision: 0.8638 - recall: 0.8435 - accuracy: 0.9778 - val_loss: 0.0246 - val_iou: 0.9754 - val_dice_coe: 0.8376 - val_precision: 0.8765 - val_recall: 0.8577 - val_accuracy: 0.9797
# Epoch 22/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0223 - iou: 0.9777 - dice_coe: 0.8174 - precision: 0.8835 - recall: 0.8641 - accuracy: 0.9812 - val_loss: 0.0261 - val_iou: 0.9739 - val_dice_coe: 0.8060 - val_precision: 0.9195 - val_recall: 0.7826 - val_accuracy: 0.9774
# Epoch 23/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0204 - iou: 0.9796 - dice_coe: 0.8342 - precision: 0.8972 - recall: 0.8688 - accuracy: 0.9831 - val_loss: 0.0209 - val_iou: 0.9791 - val_dice_coe: 0.8628 - val_precision: 0.8662 - val_recall: 0.9137 - val_accuracy: 0.9830
# Epoch 24/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0213 - iou: 0.9787 - dice_coe: 0.8288 - precision: 0.8854 - recall: 0.8717 - accuracy: 0.9821 - val_loss: 0.0340 - val_iou: 0.9660 - val_dice_coe: 0.8027 - val_precision: 0.7683 - val_recall: 0.9138 - val_accuracy: 0.9727
# Epoch 25/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0200 - iou: 0.9800 - dice_coe: 0.8410 - precision: 0.9084 - recall: 0.8690 - accuracy: 0.9834 - val_loss: 0.0253 - val_iou: 0.9747 - val_dice_coe: 0.8442 - val_precision: 0.8260 - val_recall: 0.9216 - val_accuracy: 0.9798
# Epoch 26/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0181 - iou: 0.9819 - dice_coe: 0.8481 - precision: 0.9092 - recall: 0.8803 - accuracy: 0.9848 - val_loss: 0.0185 - val_iou: 0.9815 - val_dice_coe: 0.8622 - val_precision: 0.8936 - val_recall: 0.9107 - val_accuracy: 0.9852
# Epoch 27/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0188 - iou: 0.9812 - dice_coe: 0.8504 - precision: 0.9084 - recall: 0.8861 - accuracy: 0.9845 - val_loss: 0.0180 - val_iou: 0.9820 - val_dice_coe: 0.8627 - val_precision: 0.9451 - val_recall: 0.8364 - val_accuracy: 0.9845
# Epoch 28/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0180 - iou: 0.9820 - dice_coe: 0.8526 - precision: 0.9026 - recall: 0.8933 - accuracy: 0.9852 - val_loss: 0.0196 - val_iou: 0.9804 - val_dice_coe: 0.8626 - val_precision: 0.9239 - val_recall: 0.8607 - val_accuracy: 0.9840
# Epoch 29/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0180 - iou: 0.9820 - dice_coe: 0.8534 - precision: 0.9045 - recall: 0.8885 - accuracy: 0.9850 - val_loss: 0.0233 - val_iou: 0.9767 - val_dice_coe: 0.8375 - val_precision: 0.9416 - val_recall: 0.8171 - val_accuracy: 0.9814
# Epoch 30/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0180 - iou: 0.9820 - dice_coe: 0.8510 - precision: 0.9012 - recall: 0.8895 - accuracy: 0.9850 - val_loss: 0.0199 - val_iou: 0.9801 - val_dice_coe: 0.8541 - val_precision: 0.9380 - val_recall: 0.8297 - val_accuracy: 0.9832
# Epoch 31/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0175 - iou: 0.9825 - dice_coe: 0.8558 - precision: 0.9020 - recall: 0.9007 - accuracy: 0.9859 - val_loss: 0.0195 - val_iou: 0.9805 - val_dice_coe: 0.8635 - val_precision: 0.9239 - val_recall: 0.8657 - val_accuracy: 0.9843
# Epoch 32/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0175 - iou: 0.9825 - dice_coe: 0.8586 - precision: 0.9028 - recall: 0.8925 - accuracy: 0.9856 - val_loss: 0.0163 - val_iou: 0.9837 - val_dice_coe: 0.8879 - val_precision: 0.9194 - val_recall: 0.8967 - val_accuracy: 0.9867
# Epoch 33/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0172 - iou: 0.9828 - dice_coe: 0.8635 - precision: 0.9113 - recall: 0.8972 - accuracy: 0.9860 - val_loss: 0.0231 - val_iou: 0.9769 - val_dice_coe: 0.8380 - val_precision: 0.9062 - val_recall: 0.8301 - val_accuracy: 0.9807
# Epoch 34/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0152 - iou: 0.9848 - dice_coe: 0.8785 - precision: 0.9221 - recall: 0.9067 - accuracy: 0.9876 - val_loss: 0.0156 - val_iou: 0.9844 - val_dice_coe: 0.8817 - val_precision: 0.9435 - val_recall: 0.8713 - val_accuracy: 0.9870
# Epoch 35/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0148 - iou: 0.9852 - dice_coe: 0.8790 - precision: 0.9174 - recall: 0.9088 - accuracy: 0.9880 - val_loss: 0.0181 - val_iou: 0.9819 - val_dice_coe: 0.8734 - val_precision: 0.8638 - val_recall: 0.9378 - val_accuracy: 0.9852
# Epoch 36/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0131 - iou: 0.9869 - dice_coe: 0.8945 - precision: 0.9281 - recall: 0.9232 - accuracy: 0.9894 - val_loss: 0.0142 - val_iou: 0.9858 - val_dice_coe: 0.8947 - val_precision: 0.9343 - val_recall: 0.9048 - val_accuracy: 0.9884
# Epoch 37/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0136 - iou: 0.9864 - dice_coe: 0.8894 - precision: 0.9296 - recall: 0.9134 - accuracy: 0.9889 - val_loss: 0.0158 - val_iou: 0.9842 - val_dice_coe: 0.8816 - val_precision: 0.9242 - val_recall: 0.9068 - val_accuracy: 0.9874
# Epoch 38/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0130 - iou: 0.9870 - dice_coe: 0.8917 - precision: 0.9366 - recall: 0.9121 - accuracy: 0.9893 - val_loss: 0.0131 - val_iou: 0.9869 - val_dice_coe: 0.9039 - val_precision: 0.9454 - val_recall: 0.9000 - val_accuracy: 0.9891
# Epoch 39/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0127 - iou: 0.9873 - dice_coe: 0.8966 - precision: 0.9328 - recall: 0.9183 - accuracy: 0.9895 - val_loss: 0.0147 - val_iou: 0.9853 - val_dice_coe: 0.9079 - val_precision: 0.9349 - val_recall: 0.9100 - val_accuracy: 0.9881
# Epoch 40/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0136 - iou: 0.9864 - dice_coe: 0.8837 - precision: 0.9224 - recall: 0.9086 - accuracy: 0.9886 - val_loss: 0.0283 - val_iou: 0.9717 - val_dice_coe: 0.8302 - val_precision: 0.8737 - val_recall: 0.8346 - val_accuracy: 0.9775
# Epoch 41/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0152 - iou: 0.9848 - dice_coe: 0.8729 - precision: 0.9101 - recall: 0.9022 - accuracy: 0.9873 - val_loss: 0.0148 - val_iou: 0.9852 - val_dice_coe: 0.8901 - val_precision: 0.9229 - val_recall: 0.9009 - val_accuracy: 0.9876
# Epoch 42/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0130 - iou: 0.9870 - dice_coe: 0.8939 - precision: 0.9313 - recall: 0.9148 - accuracy: 0.9889 - val_loss: 0.0154 - val_iou: 0.9846 - val_dice_coe: 0.8864 - val_precision: 0.9482 - val_recall: 0.8754 - val_accuracy: 0.9872
# Epoch 43/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0117 - iou: 0.9883 - dice_coe: 0.9055 - precision: 0.9383 - recall: 0.9262 - accuracy: 0.9904 - val_loss: 0.0141 - val_iou: 0.9859 - val_dice_coe: 0.9038 - val_precision: 0.9251 - val_recall: 0.9200 - val_accuracy: 0.9885
# Epoch 44/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0122 - iou: 0.9878 - dice_coe: 0.8987 - precision: 0.9314 - recall: 0.9227 - accuracy: 0.9897 - val_loss: 0.0198 - val_iou: 0.9802 - val_dice_coe: 0.8579 - val_precision: 0.8651 - val_recall: 0.9126 - val_accuracy: 0.9837
# Epoch 45/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0131 - iou: 0.9869 - dice_coe: 0.8945 - precision: 0.9261 - recall: 0.9215 - accuracy: 0.9894 - val_loss: 0.0129 - val_iou: 0.9871 - val_dice_coe: 0.9120 - val_precision: 0.9122 - val_recall: 0.9486 - val_accuracy: 0.9896
# Epoch 46/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0131 - iou: 0.9869 - dice_coe: 0.8930 - precision: 0.9242 - recall: 0.9165 - accuracy: 0.9889 - val_loss: 0.0161 - val_iou: 0.9839 - val_dice_coe: 0.8868 - val_precision: 0.9596 - val_recall: 0.8564 - val_accuracy: 0.9866
# Epoch 47/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0118 - iou: 0.9882 - dice_coe: 0.9048 - precision: 0.9342 - recall: 0.9282 - accuracy: 0.9905 - val_loss: 0.0125 - val_iou: 0.9875 - val_dice_coe: 0.9170 - val_precision: 0.9139 - val_recall: 0.9507 - val_accuracy: 0.9900
# Epoch 48/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0108 - iou: 0.9892 - dice_coe: 0.9100 - precision: 0.9389 - recall: 0.9272 - accuracy: 0.9909 - val_loss: 0.0117 - val_iou: 0.9883 - val_dice_coe: 0.9189 - val_precision: 0.9291 - val_recall: 0.9412 - val_accuracy: 0.9906
# Epoch 49/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0120 - iou: 0.9880 - dice_coe: 0.9018 - precision: 0.9316 - recall: 0.9231 - accuracy: 0.9900 - val_loss: 0.0151 - val_iou: 0.9849 - val_dice_coe: 0.8879 - val_precision: 0.9309 - val_recall: 0.8996 - val_accuracy: 0.9875
# Epoch 50/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0120 - iou: 0.9880 - dice_coe: 0.9018 - precision: 0.9349 - recall: 0.9235 - accuracy: 0.9903 - val_loss: 0.0375 - val_iou: 0.9625 - val_dice_coe: 0.7485 - val_precision: 0.9460 - val_recall: 0.6559 - val_accuracy: 0.9699
# Epoch 51/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0119 - iou: 0.9881 - dice_coe: 0.9016 - precision: 0.9363 - recall: 0.9210 - accuracy: 0.9901 - val_loss: 0.0123 - val_iou: 0.9877 - val_dice_coe: 0.9114 - val_precision: 0.9156 - val_recall: 0.9427 - val_accuracy: 0.9898
# Epoch 52/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0118 - iou: 0.9882 - dice_coe: 0.9017 - precision: 0.9336 - recall: 0.9237 - accuracy: 0.9902 - val_loss: 0.0126 - val_iou: 0.9874 - val_dice_coe: 0.9040 - val_precision: 0.9756 - val_recall: 0.8682 - val_accuracy: 0.9892
# Epoch 53/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0107 - iou: 0.9893 - dice_coe: 0.9165 - precision: 0.9419 - recall: 0.9351 - accuracy: 0.9913 - val_loss: 0.0109 - val_iou: 0.9891 - val_dice_coe: 0.9210 - val_precision: 0.9344 - val_recall: 0.9402 - val_accuracy: 0.9911
# Epoch 54/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0097 - iou: 0.9903 - dice_coe: 0.9205 - precision: 0.9439 - recall: 0.9420 - accuracy: 0.9920 - val_loss: 0.0117 - val_iou: 0.9883 - val_dice_coe: 0.9169 - val_precision: 0.9687 - val_recall: 0.8952 - val_accuracy: 0.9903
# Epoch 55/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0099 - iou: 0.9901 - dice_coe: 0.9179 - precision: 0.9402 - recall: 0.9445 - accuracy: 0.9921 - val_loss: 0.0116 - val_iou: 0.9884 - val_dice_coe: 0.9252 - val_precision: 0.9451 - val_recall: 0.9291 - val_accuracy: 0.9906
# Epoch 56/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0102 - iou: 0.9898 - dice_coe: 0.9132 - precision: 0.9357 - recall: 0.9409 - accuracy: 0.9916 - val_loss: 0.0123 - val_iou: 0.9877 - val_dice_coe: 0.9143 - val_precision: 0.9132 - val_recall: 0.9481 - val_accuracy: 0.9898
# Epoch 57/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0108 - iou: 0.9892 - dice_coe: 0.9123 - precision: 0.9353 - recall: 0.9379 - accuracy: 0.9912 - val_loss: 0.0132 - val_iou: 0.9868 - val_dice_coe: 0.9168 - val_precision: 0.9317 - val_recall: 0.9241 - val_accuracy: 0.9894
# Epoch 58/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0120 - iou: 0.9880 - dice_coe: 0.9041 - precision: 0.9286 - recall: 0.9346 - accuracy: 0.9903 - val_loss: 0.0150 - val_iou: 0.9850 - val_dice_coe: 0.8976 - val_precision: 0.9338 - val_recall: 0.9018 - val_accuracy: 0.9875
# Epoch 59/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0109 - iou: 0.9891 - dice_coe: 0.9064 - precision: 0.9312 - recall: 0.9371 - accuracy: 0.9910 - val_loss: 0.0121 - val_iou: 0.9879 - val_dice_coe: 0.9200 - val_precision: 0.9170 - val_recall: 0.9527 - val_accuracy: 0.9902
# Epoch 60/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0112 - iou: 0.9888 - dice_coe: 0.9129 - precision: 0.9336 - recall: 0.9393 - accuracy: 0.9909 - val_loss: 0.0120 - val_iou: 0.9880 - val_dice_coe: 0.9118 - val_precision: 0.9603 - val_recall: 0.9061 - val_accuracy: 0.9901
# Epoch 61/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0095 - iou: 0.9905 - dice_coe: 0.9153 - precision: 0.9352 - recall: 0.9473 - accuracy: 0.9922 - val_loss: 0.0111 - val_iou: 0.9889 - val_dice_coe: 0.9239 - val_precision: 0.9446 - val_recall: 0.9348 - val_accuracy: 0.9910
# Epoch 62/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0114 - iou: 0.9886 - dice_coe: 0.9104 - precision: 0.9323 - recall: 0.9367 - accuracy: 0.9907 - val_loss: 0.0167 - val_iou: 0.9833 - val_dice_coe: 0.8799 - val_precision: 0.9401 - val_recall: 0.8688 - val_accuracy: 0.9864
# Epoch 63/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0102 - iou: 0.9898 - dice_coe: 0.9165 - precision: 0.9368 - recall: 0.9436 - accuracy: 0.9916 - val_loss: 0.0121 - val_iou: 0.9879 - val_dice_coe: 0.9154 - val_precision: 0.9660 - val_recall: 0.9007 - val_accuracy: 0.9903
# Epoch 64/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0094 - iou: 0.9906 - dice_coe: 0.9185 - precision: 0.9350 - recall: 0.9479 - accuracy: 0.9923 - val_loss: 0.0098 - val_iou: 0.9902 - val_dice_coe: 0.9288 - val_precision: 0.9614 - val_recall: 0.9273 - val_accuracy: 0.9920
# Epoch 65/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0090 - iou: 0.9910 - dice_coe: 0.9238 - precision: 0.9447 - recall: 0.9474 - accuracy: 0.9926 - val_loss: 0.0102 - val_iou: 0.9898 - val_dice_coe: 0.9236 - val_precision: 0.9502 - val_recall: 0.9335 - val_accuracy: 0.9916
# Epoch 66/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0107 - iou: 0.9893 - dice_coe: 0.9144 - precision: 0.9354 - recall: 0.9428 - accuracy: 0.9910 - val_loss: 0.0302 - val_iou: 0.9698 - val_dice_coe: 0.7878 - val_precision: 0.9394 - val_recall: 0.7227 - val_accuracy: 0.9755
# Epoch 67/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0111 - iou: 0.9889 - dice_coe: 0.9078 - precision: 0.9284 - recall: 0.9397 - accuracy: 0.9911 - val_loss: 0.0097 - val_iou: 0.9903 - val_dice_coe: 0.9267 - val_precision: 0.9337 - val_recall: 0.9549 - val_accuracy: 0.9920
# Epoch 68/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0102 - iou: 0.9898 - dice_coe: 0.9147 - precision: 0.9307 - recall: 0.9460 - accuracy: 0.9918 - val_loss: 0.0103 - val_iou: 0.9897 - val_dice_coe: 0.9263 - val_precision: 0.9361 - val_recall: 0.9482 - val_accuracy: 0.9914
# Epoch 69/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0088 - iou: 0.9912 - dice_coe: 0.9230 - precision: 0.9410 - recall: 0.9514 - accuracy: 0.9928 - val_loss: 0.0107 - val_iou: 0.9893 - val_dice_coe: 0.9240 - val_precision: 0.9280 - val_recall: 0.9479 - val_accuracy: 0.9910
# Epoch 70/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0090 - iou: 0.9910 - dice_coe: 0.9262 - precision: 0.9444 - recall: 0.9492 - accuracy: 0.9926 - val_loss: 0.0100 - val_iou: 0.9900 - val_dice_coe: 0.9283 - val_precision: 0.9262 - val_recall: 0.9590 - val_accuracy: 0.9916
# Epoch 71/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0086 - iou: 0.9914 - dice_coe: 0.9265 - precision: 0.9446 - recall: 0.9519 - accuracy: 0.9930 - val_loss: 0.0107 - val_iou: 0.9893 - val_dice_coe: 0.9300 - val_precision: 0.9159 - val_recall: 0.9679 - val_accuracy: 0.9912
# Epoch 72/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0082 - iou: 0.9918 - dice_coe: 0.9311 - precision: 0.9498 - recall: 0.9508 - accuracy: 0.9932 - val_loss: 0.0099 - val_iou: 0.9901 - val_dice_coe: 0.9261 - val_precision: 0.9458 - val_recall: 0.9382 - val_accuracy: 0.9919
# Epoch 73/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0082 - iou: 0.9918 - dice_coe: 0.9275 - precision: 0.9445 - recall: 0.9534 - accuracy: 0.9930 - val_loss: 0.0094 - val_iou: 0.9906 - val_dice_coe: 0.9347 - val_precision: 0.9390 - val_recall: 0.9555 - val_accuracy: 0.9924
# Epoch 74/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0115 - iou: 0.9885 - dice_coe: 0.9066 - precision: 0.9240 - recall: 0.9402 - accuracy: 0.9905 - val_loss: 0.0111 - val_iou: 0.9889 - val_dice_coe: 0.9215 - val_precision: 0.9477 - val_recall: 0.9247 - val_accuracy: 0.9909
# Epoch 75/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0099 - iou: 0.9901 - dice_coe: 0.9207 - precision: 0.9360 - recall: 0.9491 - accuracy: 0.9918 - val_loss: 0.0128 - val_iou: 0.9872 - val_dice_coe: 0.9093 - val_precision: 0.9266 - val_recall: 0.9299 - val_accuracy: 0.9893
# Epoch 76/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0098 - iou: 0.9902 - dice_coe: 0.9246 - precision: 0.9465 - recall: 0.9490 - accuracy: 0.9924 - val_loss: 0.0112 - val_iou: 0.9888 - val_dice_coe: 0.9238 - val_precision: 0.9382 - val_recall: 0.9343 - val_accuracy: 0.9910
# Epoch 77/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0101 - iou: 0.9899 - dice_coe: 0.9180 - precision: 0.9378 - recall: 0.9453 - accuracy: 0.9918 - val_loss: 0.0105 - val_iou: 0.9895 - val_dice_coe: 0.9249 - val_precision: 0.9460 - val_recall: 0.9348 - val_accuracy: 0.9914
# Epoch 78/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0086 - iou: 0.9914 - dice_coe: 0.9293 - precision: 0.9465 - recall: 0.9531 - accuracy: 0.9930 - val_loss: 0.0093 - val_iou: 0.9907 - val_dice_coe: 0.9340 - val_precision: 0.9376 - val_recall: 0.9563 - val_accuracy: 0.9923
# Epoch 79/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0083 - iou: 0.9917 - dice_coe: 0.9299 - precision: 0.9436 - recall: 0.9559 - accuracy: 0.9932 - val_loss: 0.0099 - val_iou: 0.9901 - val_dice_coe: 0.9277 - val_precision: 0.9355 - val_recall: 0.9505 - val_accuracy: 0.9918
# Epoch 80/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0086 - iou: 0.9914 - dice_coe: 0.9280 - precision: 0.9432 - recall: 0.9523 - accuracy: 0.9929 - val_loss: 0.0095 - val_iou: 0.9905 - val_dice_coe: 0.9289 - val_precision: 0.9665 - val_recall: 0.9253 - val_accuracy: 0.9924
# Epoch 81/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0086 - iou: 0.9914 - dice_coe: 0.9317 - precision: 0.9493 - recall: 0.9517 - accuracy: 0.9930 - val_loss: 0.0104 - val_iou: 0.9896 - val_dice_coe: 0.9290 - val_precision: 0.9660 - val_recall: 0.9161 - val_accuracy: 0.9916
# Epoch 82/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0081 - iou: 0.9919 - dice_coe: 0.9328 - precision: 0.9494 - recall: 0.9530 - accuracy: 0.9933 - val_loss: 0.0383 - val_iou: 0.9617 - val_dice_coe: 0.7357 - val_precision: 0.9178 - val_recall: 0.6630 - val_accuracy: 0.9708
# Epoch 83/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0089 - iou: 0.9911 - dice_coe: 0.9272 - precision: 0.9464 - recall: 0.9483 - accuracy: 0.9928 - val_loss: 0.0096 - val_iou: 0.9904 - val_dice_coe: 0.9336 - val_precision: 0.9495 - val_recall: 0.9433 - val_accuracy: 0.9922
# Epoch 84/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0083 - iou: 0.9917 - dice_coe: 0.9344 - precision: 0.9510 - recall: 0.9533 - accuracy: 0.9931 - val_loss: 0.0092 - val_iou: 0.9908 - val_dice_coe: 0.9350 - val_precision: 0.9400 - val_recall: 0.9555 - val_accuracy: 0.9925
# Epoch 85/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0083 - iou: 0.9917 - dice_coe: 0.9332 - precision: 0.9492 - recall: 0.9533 - accuracy: 0.9931 - val_loss: 0.0101 - val_iou: 0.9899 - val_dice_coe: 0.9263 - val_precision: 0.9327 - val_recall: 0.9493 - val_accuracy: 0.9916
# Epoch 86/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0081 - iou: 0.9919 - dice_coe: 0.9293 - precision: 0.9439 - recall: 0.9550 - accuracy: 0.9933 - val_loss: 0.0088 - val_iou: 0.9912 - val_dice_coe: 0.9374 - val_precision: 0.9370 - val_recall: 0.9608 - val_accuracy: 0.9926
# Epoch 87/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0083 - iou: 0.9917 - dice_coe: 0.9306 - precision: 0.9488 - recall: 0.9536 - accuracy: 0.9932 - val_loss: 0.0098 - val_iou: 0.9902 - val_dice_coe: 0.9321 - val_precision: 0.9518 - val_recall: 0.9387 - val_accuracy: 0.9920
# Epoch 88/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0079 - iou: 0.9921 - dice_coe: 0.9366 - precision: 0.9535 - recall: 0.9557 - accuracy: 0.9935 - val_loss: 0.0086 - val_iou: 0.9914 - val_dice_coe: 0.9387 - val_precision: 0.9517 - val_recall: 0.9487 - val_accuracy: 0.9929
# Epoch 89/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0089 - iou: 0.9911 - dice_coe: 0.9280 - precision: 0.9432 - recall: 0.9490 - accuracy: 0.9925 - val_loss: 0.0095 - val_iou: 0.9905 - val_dice_coe: 0.9330 - val_precision: 0.9441 - val_recall: 0.9468 - val_accuracy: 0.9919
# Epoch 90/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0076 - iou: 0.9924 - dice_coe: 0.9371 - precision: 0.9515 - recall: 0.9568 - accuracy: 0.9936 - val_loss: 0.0089 - val_iou: 0.9911 - val_dice_coe: 0.9337 - val_precision: 0.9576 - val_recall: 0.9375 - val_accuracy: 0.9926
# Epoch 91/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0078 - iou: 0.9922 - dice_coe: 0.9348 - precision: 0.9504 - recall: 0.9546 - accuracy: 0.9935 - val_loss: 0.0124 - val_iou: 0.9876 - val_dice_coe: 0.9117 - val_precision: 0.9757 - val_recall: 0.8886 - val_accuracy: 0.9902
# Epoch 92/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0081 - iou: 0.9919 - dice_coe: 0.9342 - precision: 0.9507 - recall: 0.9527 - accuracy: 0.9933 - val_loss: 0.0098 - val_iou: 0.9902 - val_dice_coe: 0.9332 - val_precision: 0.9624 - val_recall: 0.9257 - val_accuracy: 0.9919
# Epoch 93/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0087 - iou: 0.9913 - dice_coe: 0.9235 - precision: 0.9405 - recall: 0.9498 - accuracy: 0.9929 - val_loss: 0.0136 - val_iou: 0.9864 - val_dice_coe: 0.9073 - val_precision: 0.9275 - val_recall: 0.9193 - val_accuracy: 0.9885
# Epoch 94/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0081 - iou: 0.9919 - dice_coe: 0.9328 - precision: 0.9497 - recall: 0.9548 - accuracy: 0.9933 - val_loss: 0.0089 - val_iou: 0.9911 - val_dice_coe: 0.9376 - val_precision: 0.9598 - val_recall: 0.9379 - val_accuracy: 0.9927
# Epoch 95/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0095 - iou: 0.9905 - dice_coe: 0.9216 - precision: 0.9397 - recall: 0.9464 - accuracy: 0.9922 - val_loss: 0.0148 - val_iou: 0.9852 - val_dice_coe: 0.9069 - val_precision: 0.9163 - val_recall: 0.9233 - val_accuracy: 0.9876
# Epoch 96/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0086 - iou: 0.9914 - dice_coe: 0.9300 - precision: 0.9465 - recall: 0.9529 - accuracy: 0.9929 - val_loss: 0.0101 - val_iou: 0.9899 - val_dice_coe: 0.9284 - val_precision: 0.9602 - val_recall: 0.9234 - val_accuracy: 0.9919
# Epoch 97/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0078 - iou: 0.9922 - dice_coe: 0.9353 - precision: 0.9482 - recall: 0.9559 - accuracy: 0.9935 - val_loss: 0.0092 - val_iou: 0.9908 - val_dice_coe: 0.9344 - val_precision: 0.9524 - val_recall: 0.9428 - val_accuracy: 0.9925
# Epoch 98/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0074 - iou: 0.9926 - dice_coe: 0.9407 - precision: 0.9551 - recall: 0.9584 - accuracy: 0.9938 - val_loss: 0.0107 - val_iou: 0.9893 - val_dice_coe: 0.9234 - val_precision: 0.9592 - val_recall: 0.9189 - val_accuracy: 0.9912
# Epoch 99/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0077 - iou: 0.9923 - dice_coe: 0.9372 - precision: 0.9521 - recall: 0.9576 - accuracy: 0.9936 - val_loss: 0.0086 - val_iou: 0.9914 - val_dice_coe: 0.9369 - val_precision: 0.9450 - val_recall: 0.9551 - val_accuracy: 0.9928
# Epoch 100/100
# 364/364 [==============================] - 18s 50ms/step - loss: 0.0073 - iou: 0.9927 - dice_coe: 0.9394 - precision: 0.9520 - recall: 0.9595 - accuracy: 0.9939 - val_loss: 0.0084 - val_iou: 0.9916 - val_dice_coe: 0.9377 - val_precision: 0.9622 - val_recall: 0.9391 - val_accuracy: 0.9931

# %%
model_1 = Model(inputs, pred, name="UNET_224")
model_1.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])

# %%
model_1.load_weights('/content/drive/My Drive/models/dgu_unet_100_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 364/364 [==============================] - 4s 12ms/step
# ________________________
# IOU:       |   99.37  |
# Dice Coef: |   94.96  |
# Precision: |   96.81  |
# Recall:    |   95.54  |
# Accuracy:  |   99.46  |
# Loss:      |   0.63  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 26/26 [==============================] - 0s 10ms/step
# ________________________
# IOU:       |   98.85  |
# Dice Coef: |   91.73  |
# Precision: |   96.49  |
# Recall:    |   89.39  |
# Accuracy:  |   98.80  |
# Loss:      |   1.15  |
# ________________________
#
# -------------On validation Set---------------------
#
# 92/92 [==============================] - 1s 10ms/step
# ________________________
# IOU:       |   99.16  |
# Dice Coef: |   94.53  |
# Precision: |   96.76  |
# Recall:    |   94.76  |
# Accuracy:  |   99.36  |
# Loss:      |   0.84  |
# ________________________

# %%
def enhance(img):
    model_1.load_weights('/content/drive/My Drive/models/dgu_unet_100_epoch.h5')
    sub = (model_1.predict(img.reshape(1,224,224,3))).flatten()

    # for i in range(len(sub)):
    #     if sub[i] <= 0.165:
    #         sub[i] = 0
    #     elif sub[i] <= 0.97:
    #         sub[i] = 1
    #     else:
    #         sub[i] = 2
    return sub

# %%
plt.suptitle('Comparing the Prediction after enhancement')
for i in range(len(x_test)):
  plt.figure(figsize=(12,12))
  plt.subplot(5,3,1 + i*3)
  plt.title('Origin Image')
  plt.imshow(x_test[i],plt.cm.binary_r)
  plt.subplot(5,3,2 + i*3)
  plt.title('Ground Truth_in')
  plt.imshow(y_test[i],plt.cm.binary_r)
  plt.subplot(5,3,3 + i*3)
  plt.title('Predicted_in')
  plt.imshow(enhance(x_test[i]).reshape(224,224), plt.cm.binary_r)
  # plt.subplot(5,3,4 + i*3)
  # plt.title('Ground_Truth_out')
  # plt.imshow(y_test_out[i],plt.cm.binary_r)
  # plt.subplot(5,3,5 + i*3)
  # plt.title('Predicted_out')
  # plt.imshow(enhance_out(x_test_out[i]).reshape(224,224),plt.cm.binary_r)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-31156934cd78> in <module>()
#      11   plt.title('Predicted_in')
#      12   plt.imshow(enhance(x_test[i]).reshape(224,224), plt.cm.binary_r)
# ---> 13   plt.subplot(5,3,4 + i*3)
#      14   # plt.title('Ground_Truth_out')
#      15   # plt.imshow(y_test_out[i],plt.cm.binary_r)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      64                 if num < 1 or num > rows*cols:
#      65                     raise ValueError(
# ---> 66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#      68                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 15, not 16

# %%
for i in range(len(X_train)):
  plt.figure(figsize=(12,4))
  plt.subplot(1,3,1)
  plt.title('Origin Image')
  plt.imshow(X_train[i])
  plt.subplot(1,3,2)
  plt.title('Ground Truth')
  plt.imshow(Y_train[i], plt.cm.binary_r)
  plt.subplot(1,3,3)
  plt.title('Predicted')
  plt.imshow(enhance(X_train[i]).reshape(224,224), plt.cm.binary_r)
  # plt.subplot(3,2,5)
  # plt.title('Ground_Truth_out')
  # plt.imshow(Y_train_out[i],plt.cm.binary_r)
  # plt.subplot(3,2,6)
  # plt.title('Predicted_out')
  # plt.imshow(enhance_out(X_train[i]).reshape(224,224),plt.cm.binary_r)
  plt.savefig('/content/drive/My Drive/results/total/results/' + str(i) + '.jpg')

  # model_1.load_weights('dgu_unet_100_epoch_in.h5')
  # predictions_in =model_1.predict(x_train_full_in[i].reshape(1,224,224,3))
  # model_1.load_weights('dgu_unet_100_epoch_out.h5')
  # predictions_out = model_1.predict(x_train_full_out[i].reshape(1,224,224,3))
  # prediction_in = predictions_in.reshape(224, 224)
  # prediction_out = predictions_out.reshape(224,224)
  # plt.imsave('/content/drive/My Drive/results/dgu_improved_100epoch_3batch/result_x/' + str(i) + '_x.jpg', x_train_full[i])
  # plt.imsave('/content/drive/My Drive/results/dgu_improved_100epoch_3batch/result_y/' + str(i) + '_y.jpg', y_train_full[i])
  # plt.imsave('/content/drive/My Drive/results/dgu_improved_100epoch_3batch/results/' + str(i) + '.jpg', prediction)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
